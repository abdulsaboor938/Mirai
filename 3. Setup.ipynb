# %%
# !pip install pandas
# !pip install numpy
import pandas as pd
import numpy as np
# Fuction
def combine_predictions(zone):

    temp = pd.read_csv(f'raw_data/{zone}.csv')

    temp['pred_temp'] = np.nan
    temp['pred_pm25'] = np.nan
    temp['pred_pm10'] = np.nan
    temp['pred_smog'] = np.nan

    temp1 = pd.read_csv(f'prediction/{zone}.csv')
    temp1.columns = ['date','zone','longitude','latitude','pred_temp','pred_pm25','pred_pm10','pred_smog']

    temp1['temperature'] = np.nan
    temp1['pm2_5']=np.nan
    temp1['pm10']=np.nan
    temp1['smog']=np.nan

    temp1=temp1[['date','zone','longitude','latitude','temperature','pm2_5','pm10','smog','pred_temp','pred_pm25','pred_pm10','pred_smog']]

    return(pd.concat([temp,temp1]))

# check if final_data.csv exists
import os.path
from os import path
if path.exists("final_data.csv"):
    print("final_data.csv exists")
else:
    # Writing back to files
    df = combine_predictions(1)
    df.to_csv('final_data.csv', index=False)

    for i in range(2,249):
        combine_predictions(i).to_csv('final_data.csv', mode='a', header=False, index=False)
        print(f"{i} done")
# Out:
# Requirement already satisfied: pandas in /Users/carbon/miniconda3/envs/tensorflow/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/carbon/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/carbon/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/carbon/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/carbon/miniconda3/envs/tensorflow/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in /Users/carbon/miniconda3/envs/tensorflow/lib/python3.10/site-packages (1.23.5)
# final_data.csv exists

# %%
# # metabase operations

# going to metabase folder
# %cd ./metabase

# check if metabase.jar is present, if not download it
import os.path
from os import path
if path.exists("metabase.jar"):
    print("File exists")
else:
    print("File does not exist, downloading...")
    # !wget http://downloads.metabase.com/v0.38.2/metabase.jar

# run metabase
# !java -jar metabase.jar
# Out:
# [Errno 2] No such file or directory: './metabase'
# /Users/carbon/Desktop/meta/metabase
# File exists
# Warning: protocol #'java-time.core/Amount is overwriting function abs
# WARNING: abs already refers to: #'clojure.core/abs in namespace: java-time.core, being replaced by: #'java-time.core/abs
# WARNING: abs already refers to: #'clojure.core/abs in namespace: java-time, being replaced by: #'java-time/abs
# 2023-05-13 15:32:16,618 INFO metabase.util :: Maximum memory available to JVM: 2.0 GB
# 2023-05-13 15:32:17,182 WARN db.env :: WARNING: Using Metabase with an H2 application database is not recommended for production deployments. For production deployments, we highly recommend using Postgres, MySQL, or MariaDB instead. If you decide to continue to use H2, please be sure to back up the database file regularly. For more information, see https://metabase.com/docs/latest/operations-guide/migrating-from-h2.html
# 2023-05-13 15:32:17,547 INFO util.encryption :: Saved credentials encryption is DISABLED for this Metabase instance. 🔓
#  For more information, see https://metabase.com/docs/latest/operations-guide/encrypting-database-details-at-rest.html
# WARNING: abs already refers to: #'clojure.core/abs in namespace: taoensso.encore, being replaced by: #'taoensso.encore/abs
# WARNING: abs already refers to: #'clojure.core/abs in namespace: kixi.stats.math, being replaced by: #'kixi.stats.math/abs
# WARNING: abs already refers to: #'clojure.core/abs in namespace: kixi.stats.test, being replaced by: #'kixi.stats.math/abs
# WARNING: abs already refers to: #'clojure.core/abs in namespace: kixi.stats.distribution, being replaced by: #'kixi.stats.math/abs
# 2023-05-13 15:32:20,029 INFO driver.impl :: Registered abstract driver :sql  🚚
# 2023-05-13 15:32:20,030 INFO metabase.util ::  ⮦ Load driver :sql took 43.6 ms
# 2023-05-13 15:32:20,035 INFO driver.impl :: Registered abstract driver :sql-jdbc (parents: [:sql]) 🚚
# 2023-05-13 15:32:20,037 INFO metabase.util :: Load driver :sql-jdbc took 51.5 ms
# 2023-05-13 15:32:20,037 INFO driver.impl :: Registered driver :h2 (parents: [:sql-jdbc]) 🚚
# 2023-05-13 15:32:20,052 INFO driver.impl :: Registered driver :mysql (parents: [:sql-jdbc]) 🚚
# 2023-05-13 15:32:20,067 INFO driver.impl :: Registered driver :postgres (parents: [:sql-jdbc]) 🚚
# 2023-05-13 15:32:21,023 INFO metabase.core ::
# Metabase v0.45.2 (819ce29 release-x.45.x)
#
# Copyright © 2023 Metabase, Inc.
#
# Metabase Enterprise Edition extensions are NOT PRESENT.
# 2023-05-13 15:32:21,042 INFO metabase.core :: Starting Metabase in STANDALONE mode
# 2023-05-13 15:32:21,069 INFO metabase.server :: Launching Embedded Jetty Webserver with config:
#  {:port 3000}
#
# 2023-05-13 15:32:21,122 INFO metabase.core :: Starting Metabase version v0.45.2 (819ce29 release-x.45.x) ...
# 2023-05-13 15:32:21,137 INFO metabase.core :: System info:
#  {"file.encoding" "UTF-8",
#  "java.runtime.name" "OpenJDK Runtime Environment",
#  "java.runtime.version" "17.0.6+10",
#  "java.vendor" "Eclipse Adoptium",
#  "java.vendor.url" "https://adoptium.net/",
#  "java.version" "17.0.6",
#  "java.vm.name" "OpenJDK 64-Bit Server VM",
#  "java.vm.version" "17.0.6+10",
#  "os.name" "Mac OS X",
#  "os.version" "13.2.1",
#  "user.language" "en",
#  "user.timezone" "Asia/Karachi"}
#
# 2023-05-13 15:32:21,140 INFO metabase.plugins :: Loading plugins in /Users/carbon/Desktop/meta/metabase/plugins...
# 2023-05-13 15:32:21,247 INFO util.files :: Extract file /modules/sparksql.metabase-driver.jar -> /Users/carbon/Desktop/meta/metabase/plugins/sparksql.metabase-driver.jar
# 2023-05-13 15:32:21,323 INFO util.files :: Extract file /modules/athena.metabase-driver.jar -> /Users/carbon/Desktop/meta/metabase/plugins/athena.metabase-driver.jar
# 2023-05-13 15:32:21,429 INFO util.files :: Extract file /modules/sqlserver.metabase-driver.jar -> /Users/carbon/Desktop/meta/metabase/plugins/sqlserver.metabase-driver.jar
# 2023-05-13 15:32:21,446 INFO util.files :: Extract file /modules/presto-jdbc.metabase-driver.jar -> /Users/carbon/Desktop/meta/metabase/plugins/presto-jdbc.metabase-driver.jar
# 2023-05-13 15:32:21,523 INFO util.files :: Extract file /modules/sqlite.metabase-driver.jar -> /Users/carbon/Desktop/meta/metabase/plugins/sqlite.metabase-driver.jar
# 2023-05-13 15:32:21,554 INFO util.files :: Extract file /modules/vertica.metabase-driver.jar -> /Users/carbon/Desktop/meta/metabase/plugins/vertica.metabase-driver.jar
# 2023-05-13 15:32:21,558 INFO util.files :: Extract file /modules/redshift.metabase-driver.jar -> /Users/carbon/Desktop/meta/metabase/plugins/redshift.metabase-driver.jar
# 2023-05-13 15:32:21,574 INFO util.files :: Extract file /modules/presto.metabase-driver.jar -> /Users/carbon/Desktop/meta/metabase/plugins/presto.metabase-driver.jar
# 2023-05-13 15:32:21,576 INFO util.files :: Extract file /modules/druid.metabase-driver.jar -> /Users/carbon/Desktop/meta/metabase/plugins/druid.metabase-driver.jar
# 2023-05-13 15:32:21,583 INFO util.files :: Extract file /modules/mongo.metabase-driver.jar -> /Users/carbon/Desktop/meta/metabase/plugins/mongo.metabase-driver.jar
# 2023-05-13 15:32:21,606 INFO util.files :: Extract file /modules/oracle.metabase-driver.jar -> /Users/carbon/Desktop/meta/metabase/plugins/oracle.metabase-driver.jar
# 2023-05-13 15:32:21,613 INFO util.files :: Extract file /modules/snowflake.metabase-driver.jar -> /Users/carbon/Desktop/meta/metabase/plugins/snowflake.metabase-driver.jar
# 2023-05-13 15:32:21,876 INFO util.files :: Extract file /modules/googleanalytics.metabase-driver.jar -> /Users/carbon/Desktop/meta/metabase/plugins/googleanalytics.metabase-driver.jar
# 2023-05-13 15:32:21,903 INFO util.files :: Extract file /modules/bigquery-cloud-sdk.metabase-driver.jar -> /Users/carbon/Desktop/meta/metabase/plugins/bigquery-cloud-sdk.metabase-driver.jar
# 2023-05-13 15:32:21,971 INFO util.files :: Extract file /modules/presto-common.metabase-driver.jar -> /Users/carbon/Desktop/meta/metabase/plugins/presto-common.metabase-driver.jar
# 2023-05-13 15:32:22,062 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :presto-common...
# 2023-05-13 15:32:22,062 INFO driver.impl :: Registered abstract driver :presto-common  🚚
# 2023-05-13 15:32:22,068 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :bigquery-cloud-sdk...
# 2023-05-13 15:32:22,075 INFO driver.impl :: Registered driver :bigquery-cloud-sdk (parents: [:sql]) 🚚
# 2023-05-13 15:32:22,079 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :googleanalytics...
# 2023-05-13 15:32:22,079 INFO driver.impl :: Registered driver :googleanalytics  🚚
# 2023-05-13 15:32:22,095 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :snowflake...
# 2023-05-13 15:32:22,095 INFO driver.impl :: Registered driver :snowflake (parents: [:sql-jdbc]) 🚚
# 2023-05-13 15:32:22,100 INFO plugins.dependencies :: Metabase cannot initialize plugin Metabase Oracle Driver due to required dependencies. Metabase requires the Oracle JDBC driver in order to connect to Oracle databases, but we can't ship it as part of Metabase due to licensing restrictions. See https://metabase.com/docs/latest/administration-guide/databases/oracle.html for more details.
#
# 2023-05-13 15:32:22,101 INFO plugins.dependencies :: Metabase Oracle Driver dependency {:class oracle.jdbc.OracleDriver} satisfied? false
# 2023-05-13 15:32:22,102 INFO plugins.dependencies :: Plugins with unsatisfied deps: ["Metabase Oracle Driver"]
# 2023-05-13 15:32:22,106 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :mongo...
# 2023-05-13 15:32:22,106 INFO driver.impl :: Registered driver :mongo  🚚
# 2023-05-13 15:32:22,109 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :druid...
# 2023-05-13 15:32:22,109 INFO driver.impl :: Registered driver :druid  🚚
# 2023-05-13 15:32:22,111 INFO plugins.dependencies :: Plugin 'Metabase Presto Driver' depends on plugin 'Presto Common Driver'
# 2023-05-13 15:32:22,112 INFO plugins.dependencies :: Metabase Presto Driver dependency {:plugin Presto Common Driver} satisfied? true
# 2023-05-13 15:32:22,113 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :presto...
# 2023-05-13 15:32:22,113 INFO driver.impl :: Registered driver :presto (parents: [:presto-common]) 🚚
# 2023-05-13 15:32:22,116 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :redshift...
# 2023-05-13 15:32:22,116 INFO driver.impl :: Registered driver :redshift (parents: [:postgres]) 🚚
# 2023-05-13 15:32:22,119 INFO plugins.dependencies :: Metabase cannot initialize plugin Metabase Vertica Driver due to required dependencies. Metabase requires the Vertica JDBC driver in order to connect to Vertica databases, but we can't ship it as part of Metabase due to licensing restrictions. See https://metabase.com/docs/latest/administration-guide/databases/vertica.html for more details.
#
# 2023-05-13 15:32:22,119 INFO plugins.dependencies :: Metabase Vertica Driver dependency {:class com.vertica.jdbc.Driver} satisfied? false
# 2023-05-13 15:32:22,120 INFO plugins.dependencies :: Plugins with unsatisfied deps: ["Metabase Oracle Driver" "Metabase Vertica Driver"]
# 2023-05-13 15:32:22,122 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :sqlite...
# 2023-05-13 15:32:22,122 INFO driver.impl :: Registered driver :sqlite (parents: [:sql-jdbc]) 🚚
# 2023-05-13 15:32:22,129 INFO plugins.dependencies :: Plugin 'Metabase Presto JDBC Driver' depends on plugin 'Presto Common Driver'
# 2023-05-13 15:32:22,130 INFO plugins.dependencies :: Metabase Presto JDBC Driver dependency {:plugin Presto Common Driver} satisfied? true
# 2023-05-13 15:32:22,130 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :presto-jdbc...
# 2023-05-13 15:32:22,130 INFO driver.impl :: Registered driver :presto-jdbc (parents: [:presto-common]) 🚚
# 2023-05-13 15:32:22,133 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :sqlserver...
# 2023-05-13 15:32:22,134 INFO driver.impl :: Registered driver :sqlserver (parents: [:sql-jdbc]) 🚚
# 2023-05-13 15:32:22,140 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :athena...
# 2023-05-13 15:32:22,141 INFO driver.impl :: Registered driver :athena (parents: [:sql-jdbc]) 🚚
# 2023-05-13 15:32:22,145 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :hive-like...
# 2023-05-13 15:32:22,145 INFO driver.impl :: Registered abstract driver :hive-like (parents: [:sql-jdbc]) 🚚
# 2023-05-13 15:32:22,146 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :sparksql...
# 2023-05-13 15:32:22,146 INFO driver.impl :: Registered driver :sparksql (parents: [:hive-like]) 🚚
# 2023-05-13 15:32:22,146 INFO metabase.core :: Setting up and migrating Metabase DB. Please sit tight, this may take a minute...
# 2023-05-13 15:32:22,151 INFO db.setup :: Verifying h2 Database Connection ...
# 2023-05-13 15:32:22,309 INFO db.setup :: Successfully verified H2 1.4.197 (2018-03-18) application database connection. ✅
# 2023-05-13 15:32:22,309 INFO db.setup :: Running Database Migrations...
# 2023-05-13 15:32:22,310 INFO db.setup :: Setting up Liquibase...
# 2023-05-13 15:32:22,412 INFO db.setup :: Liquibase is ready.
# 2023-05-13 15:32:22,412 INFO db.liquibase :: Checking if Database has unrun migrations...
# 2023-05-13 15:32:23,472 INFO db.liquibase :: Database has unrun migrations. Waiting for migration lock to be cleared...
# 2023-05-13 15:32:23,536 INFO db.liquibase :: Migration lock is cleared. Running migrations...
# 2023-05-13 15:32:25,906 INFO db.setup :: Database Migrations Current ...  ✅
# 2023-05-13 15:32:25,915 INFO db.data-migrations :: Running all necessary data migrations, this may take a minute.
# 2023-05-13 15:32:25,919 INFO db.data-migrations :: Running data migration 'migrate-click-through'...
# 2023-05-13 15:32:25,927 INFO db.data-migrations :: Running data migration 'migrate-remove-admin-from-group-mapping-if-needed'...
# 2023-05-13 15:32:25,932 INFO db.data-migrations :: Finished running data migrations.
# 2023-05-13 15:32:25,933 INFO metabase.util :: Database setup took 3.8 s
# 2023-05-13 15:32:25,958 INFO metabase.events :: Starting events listener: :metabase.events.activity-feed/ActivityFeed 👂
# 2023-05-13 15:32:25,961 INFO metabase.events :: Starting events listener: :metabase.events.last-login/LastLogin 👂
# 2023-05-13 15:32:25,962 INFO metabase.events :: Starting events listener: :metabase.events.persisted-info/PersistedInfo 👂
# 2023-05-13 15:32:25,962 INFO metabase.events :: Starting events listener: :metabase.events.sync-database/Sync 👂
# 2023-05-13 15:32:25,962 INFO metabase.events :: Starting events listener: :metabase.events.driver-notifications/DriverNotifications 👂
# 2023-05-13 15:32:25,962 INFO metabase.events :: Starting events listener: :metabase.events.revision/Revisions 👂
# 2023-05-13 15:32:25,962 INFO metabase.events :: Starting events listener: :metabase.events.view-log/ViewLog 👂
# 2023-05-13 15:32:25,980 INFO impl.StdSchedulerFactory :: Using default implementation for ThreadExecutor
# 2023-05-13 15:32:25,988 INFO core.SchedulerSignalerImpl :: Initialized Scheduler Signaller of type: class org.quartz.core.SchedulerSignalerImpl
# 2023-05-13 15:32:25,988 INFO core.QuartzScheduler :: Quartz Scheduler v.2.3.2 created.
# 2023-05-13 15:32:25,989 INFO jdbcjobstore.JobStoreTX :: Using db table-based data access locking (synchronization).
# 2023-05-13 15:32:25,990 INFO jdbcjobstore.JobStoreTX :: JobStoreTX initialized.
# 2023-05-13 15:32:25,990 INFO core.QuartzScheduler :: Scheduler meta-data: Quartz Scheduler (v2.3.2) 'MetabaseScheduler' with instanceId 'Saboors-MacBook.local1683973945982'
#   Scheduler class: 'org.quartz.core.QuartzScheduler' - running locally.
#   NOT STARTED.
#   Currently in standby mode.
#   Number of jobs executed: 0
#   Using thread pool 'org.quartz.simpl.SimpleThreadPool' - with 10 threads.
#   Using job-store 'org.quartz.impl.jdbcjobstore.JobStoreTX' - which supports persistence. and is clustered.
#
# 2023-05-13 15:32:25,990 INFO impl.StdSchedulerFactory :: Quartz scheduler 'MetabaseScheduler' initialized from default resource file in Quartz package: 'quartz.properties'
# 2023-05-13 15:32:25,990 INFO impl.StdSchedulerFactory :: Quartz scheduler version: 2.3.2
# 2023-05-13 15:32:26,069 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_Saboors-MacBook.local1683973945982 paused.
# 2023-05-13 15:32:26,069 INFO metabase.task :: Task scheduler initialized into standby mode.
# 2023-05-13 15:32:26,070 INFO metabase.task :: Initializing task SyncDatabases 📆
# 2023-05-13 15:32:26,090 INFO task.sync-databases :: Updated default schedules for 0 databases
# 2023-05-13 15:32:26,090 INFO metabase.task :: Initializing task PersistRefresh 📆
# 2023-05-13 15:32:26,097 INFO metabase.task :: Initializing task CheckForNewVersions 📆
# 2023-05-13 15:32:26,104 INFO metabase.task :: Initializing task PersistPrune 📆
# 2023-05-13 15:32:26,106 INFO metabase.task :: Initializing task SendAnonymousUsageStats 📆
# 2023-05-13 15:32:26,109 INFO metabase.task :: Initializing task RefreshSlackChannelsAndUsers 📆
# 2023-05-13 15:32:26,114 INFO metabase.task :: Initializing task SendAbandomentEmails 📆
# 2023-05-13 15:32:26,120 INFO metabase.task :: Initializing task SendPulses 📆
# 2023-05-13 15:32:26,124 INFO metabase.task :: Initializing task SendFollowUpEmails 📆
# 2023-05-13 15:32:26,128 INFO metabase.task :: Initializing task TaskHistoryCleanup 📆
# 2023-05-13 15:32:26,137 INFO metabase.core :: Looks like this is a new installation ... preparing setup wizard
# 2023-05-13 15:32:26,190 INFO metabase.core :: Please use the following URL to setup your Metabase installation:
#
# http://localhost:3000/setup/
#
#
# 2023-05-13 15:32:26,197 INFO metabase.sample-data :: Loading sample database
# 2023-05-13 15:32:26,359 INFO util.files :: Extract file /sample-database.db.mv.db -> /Users/carbon/Desktop/meta/metabase/plugins/sample-database.db.mv.db
# 2023-05-13 15:32:26,462 INFO driver.impl :: Initializing driver :sql...
# 2023-05-13 15:32:26,462 INFO driver.impl :: Initializing driver :sql-jdbc...
# 2023-05-13 15:32:26,463 INFO driver.impl :: Initializing driver :h2...
# 2023-05-13 15:32:26,499 INFO task.sync-databases :: Scheduling sync/analyze for database 1: trigger: metabase.task.sync-and-analyze.trigger.1
# 2023-05-13 15:32:26,509 INFO task.sync-databases :: Scheduling field-values for database 1: trigger: metabase.task.update-field-values.trigger.1
# 2023-05-13 15:32:26,518 INFO sync.util :: STARTING: Sync h2 Database 1 'Sample Database'
# 2023-05-13 15:32:26,648 INFO sync.util :: STARTING: Sync metadata for h2 Database 1 'Sample Database'
# 2023-05-13 15:32:26,653 INFO sync.util :: STARTING: step 'sync-timezone' for h2 Database 1 'Sample Database'
# 2023-05-13 15:32:26,737 INFO sync.util :: FINISHED: step 'sync-timezone' for h2 Database 1 'Sample Database' (84.2 ms)
# 2023-05-13 15:32:26,738 INFO sync.util :: STARTING: step 'sync-tables' for h2 Database 1 'Sample Database'
# 2023-05-13 15:32:26,754 INFO sync-metadata.tables :: Found new tables: (Table  'PUBLIC.PRODUCTS' Table  'PUBLIC.ORDERS' Table  'PUBLIC.ANALYTIC_EVENTS' Table  'PUBLIC.FEEDBACK' Table  'PUBLIC.PEOPLE' Table  'PUBLIC.INVOICES' Table  'PUBLIC.ACCOUNTS' Table  'PUBLIC.REVIEWS')
# 2023-05-13 15:32:26,787 INFO sync-metadata.tables :: Updating description for tables: (Table  'PUBLIC.ANALYTIC_EVENTS' Table  'PUBLIC.FEEDBACK' Table  'PUBLIC.PEOPLE' Table  'PUBLIC.REVIEWS' Table  'PUBLIC.ORDERS' Table  'PUBLIC.ACCOUNTS' Table  'PUBLIC.INVOICES' Table  'PUBLIC.PRODUCTS')
# 2023-05-13 15:32:26,798 INFO sync.util :: FINISHED: step 'sync-tables' for h2 Database 1 'Sample Database' (59.3 ms)
# 2023-05-13 15:32:26,798 INFO sync.util :: STARTING: step 'sync-fields' for h2 Database 1 'Sample Database'
# 2023-05-13 15:32:27,007 INFO sync.util :: FINISHED: step 'sync-fields' for h2 Database 1 'Sample Database' (208.9 ms)
# 2023-05-13 15:32:27,008 INFO sync.util :: STARTING: step 'sync-fks' for h2 Database 1 'Sample Database'
# 2023-05-13 15:32:27,018 INFO sync-metadata.fks :: Marking foreign key from Table 2 'PUBLIC.ORDERS' Field 16 'USER_ID' -> Table 5 'PUBLIC.PEOPLE' Field 35 'ID'
# 2023-05-13 15:32:27,021 INFO sync-metadata.fks :: Marking foreign key from Table 2 'PUBLIC.ORDERS' Field 9 'PRODUCT_ID' -> Table 1 'PUBLIC.PRODUCTS' Field 2 'ID'
# 2023-05-13 15:32:27,025 INFO sync-metadata.fks :: Marking foreign key from Table 3 'PUBLIC.ANALYTIC_EVENTS' Field 22 'ACCOUNT_ID' -> Table 7 'PUBLIC.ACCOUNTS' Field 60 'ID'
# 2023-05-13 15:32:27,031 INFO sync-metadata.fks :: Marking foreign key from Table 4 'PUBLIC.FEEDBACK' Field 28 'ACCOUNT_ID' -> Table 7 'PUBLIC.ACCOUNTS' Field 60 'ID'
# 2023-05-13 15:32:27,035 INFO sync-metadata.fks :: Marking foreign key from Table 6 'PUBLIC.INVOICES' Field 49 'ACCOUNT_ID' -> Table 7 'PUBLIC.ACCOUNTS' Field 60 'ID'
# 2023-05-13 15:32:27,039 INFO sync-metadata.fks :: Marking foreign key from Table 8 'PUBLIC.REVIEWS' Field 68 'PRODUCT_ID' -> Table 1 'PUBLIC.PRODUCTS' Field 2 'ID'
# 2023-05-13 15:32:27,040 INFO sync.util :: FINISHED: step 'sync-fks' for h2 Database 1 'Sample Database' (32.0 ms)
# 2023-05-13 15:32:27,047 INFO sync.util :: STARTING: step 'sync-metabase-metadata' for h2 Database 1 'Sample Database'
# 2023-05-13 15:32:27,094 INFO sync.util :: FINISHED: step 'sync-metabase-metadata' for h2 Database 1 'Sample Database' (47.1 ms)
# 2023-05-13 15:32:27,380 INFO sync.util :: FINISHED: Sync metadata for h2 Database 1 'Sample Database' (731.7 ms)
# 2023-05-13 15:32:27,381 INFO sync.util :: STARTING: Analyze data for h2 Database 1 'Sample Database'
# 2023-05-13 15:32:27,385 INFO sync.util :: STARTING: step 'fingerprint-fields' for h2 Database 1 'Sample Database'
# 2023-05-13 15:32:28,159 INFO sync.analyze :: fingerprint-fields Analyzed [*****·············································] 😢   12% Table 3 'PUBLIC.ANALYTIC_EVENTS'
# 2023-05-13 15:32:29,385 INFO sync.analyze :: fingerprint-fields Analyzed [***********·······································] 😒   24% Table 6 'PUBLIC.INVOICES'
# 2023-05-13 15:32:29,982 INFO sync.util :: FINISHED: step 'fingerprint-fields' for h2 Database 1 'Sample Database' (2.6 s)
# 2023-05-13 15:32:29,983 INFO sync.util :: STARTING: step 'classify-fields' for h2 Database 1 'Sample Database'
# 2023-05-13 15:32:30,009 INFO sync.analyze :: classify-fields Analyzed [******************································] 😕   36% Table 1 'PUBLIC.PRODUCTS'
# 2023-05-13 15:32:30,031 INFO sync.analyze :: classify-fields Analyzed [***********************···························] 😬   48% Table 4 'PUBLIC.FEEDBACK'
# 2023-05-13 15:32:30,067 INFO sync.analyze :: classify-fields Analyzed [******************************····················] 😌   60% Table 7 'PUBLIC.ACCOUNTS'
# 2023-05-13 15:32:30,073 INFO sync.util :: FINISHED: step 'classify-fields' for h2 Database 1 'Sample Database' (90.0 ms)
# 2023-05-13 15:32:30,074 INFO sync.util :: STARTING: step 'classify-tables' for h2 Database 1 'Sample Database'
# 2023-05-13 15:32:30,078 INFO sync.analyze :: classify-tables Analyzed [************************************··············] 😋   72% Table 2 'PUBLIC.ORDERS'
# 2023-05-13 15:32:30,082 INFO sync.analyze :: classify-tables Analyzed [*****************************************·········] 😊   84% Table 5 'PUBLIC.PEOPLE'
# 2023-05-13 15:32:30,085 INFO sync.analyze :: classify-tables Analyzed [***********************************************···] 😎   96% Table 8 'PUBLIC.REVIEWS'
# 2023-05-13 15:32:30,086 INFO sync.util :: FINISHED: step 'classify-tables' for h2 Database 1 'Sample Database' (12.2 ms)
# 2023-05-13 15:32:30,113 INFO sync.util :: FINISHED: Analyze data for h2 Database 1 'Sample Database' (2.7 s)
# 2023-05-13 15:32:30,115 INFO sync.util :: STARTING: Cache field values in h2 Database 1 'Sample Database'
# 2023-05-13 15:32:30,118 INFO sync.util :: STARTING: step 'delete-expired-advanced-field-values' for h2 Database 1 'Sample Database'
# 2023-05-13 15:32:30,234 INFO sync.util :: FINISHED: step 'delete-expired-advanced-field-values' for h2 Database 1 'Sample Database' (116.1 ms)
# 2023-05-13 15:32:30,235 INFO sync.util :: STARTING: step 'update-field-values' for h2 Database 1 'Sample Database'
# 2023-05-13 15:32:30,879 INFO models.field-values :: Field BODY was previously automatically set to show a list widget, but now has 231 values. Switching Field to use a search widget instead.
# 2023-05-13 15:32:31,027 INFO sync.util :: FINISHED: step 'update-field-values' for h2 Database 1 'Sample Database' (792.1 ms)
# 2023-05-13 15:32:31,035 INFO sync.util :: FINISHED: Cache field values in h2 Database 1 'Sample Database' (920.0 ms)
# 2023-05-13 15:32:31,035 INFO sync.util :: FINISHED: Sync h2 Database 1 'Sample Database' (4.5 s)
# 2023-05-13 15:32:31,038 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_Saboors-MacBook.local1683973945982 started.
# 2023-05-13 15:32:31,038 INFO metabase.task :: Task scheduler started
# 2023-05-13 15:32:31,038 INFO metabase.core :: Metabase Initialization COMPLETE
# 2023-05-13 15:32:31,049 INFO task.refresh-slack-channel-user-cache :: Slack is not configured, not refreshing slack user/channel cache.
# 2023-05-13 15:33:08,119 INFO middleware.misc :: Setting Metabase site URL to localhost:3000
# 2023-05-13 15:33:08,149 INFO i18n.impl :: Reading available locales from locales.clj...
# 2023-05-13 15:33:08,208 INFO util.fonts :: Reading available fonts from /frontend_client/app/fonts
# 2023-05-13 15:33:09,424 DEBUG middleware.log :: GET /api/user/current 401 1.9 ms (0 DB calls)
# "Unauthenticated"
#
# 2023-05-13 15:33:09,451 DEBUG middleware.log :: GET /api/session/properties 200 26.6 ms (2 DB calls) App DB connections: 0/7 Jetty threads: 5/50 (5 idle, 0 queued) (67 total active threads) Queries in flight: 0 (0 queued)
# ^C
# 2023-05-13 15:33:28,023 INFO metabase.core :: Metabase Shutting Down ...
# 2023-05-13 15:33:28,024 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_Saboors-MacBook.local1683973945982 shutting down.
# 2023-05-13 15:33:28,024 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_Saboors-MacBook.local1683973945982 paused.
# 2023-05-13 15:33:28,025 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_Saboors-MacBook.local1683973945982 shutdown complete.
# 2023-05-13 15:33:28,025 INFO metabase.server :: Shutting Down Embedded Jetty Webserver
# 2023-05-13 15:33:28,037 INFO metabase.core :: Metabase Shutdown COMPLETE
