# %%
# !pip install pandas
# !pip install numpy
import pandas as pd
import numpy as np
# Fuction
def combine_predictions(zone):

    temp = pd.read_csv(f'raw_data/{zone}.csv')

    temp['pred_temp'] = np.nan
    temp['pred_pm25'] = np.nan
    temp['pred_pm10'] = np.nan
    temp['pred_smog'] = np.nan

    temp1 = pd.read_csv(f'prediction/{zone}.csv')
    temp1.columns = ['date','zone','longitude','latitude','pred_temp','pred_pm25','pred_pm10','pred_smog']

    temp1['temperature'] = np.nan
    temp1['pm2_5']=np.nan
    temp1['pm10']=np.nan
    temp1['smog']=np.nan

    temp1=temp1[['date','zone','longitude','latitude','temperature','pm2_5','pm10','smog','pred_temp','pred_pm25','pred_pm10','pred_smog']]

    return(pd.concat([temp,temp1]))

# check if final_data.csv exists
import os.path
from os import path
if path.exists("final_data.csv"):
    print("final_data.csv exists")
else:
    # Writing back to files
    df = combine_predictions(1)
    df.to_csv('final_data.csv', index=False)

    for i in range(2,249):
        combine_predictions(i).to_csv('final_data.csv', mode='a', header=False, index=False)
        print(f"{i} done")
# Out:
# Requirement already satisfied: pandas in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: numpy in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (1.24.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# final_data.csv exists

# %%
# # metabase operations

# going to metabase folder
# %cd ./metabase

# check if metabase.jar is present, if not download it
import os.path
from os import path
if path.exists("metabase.jar"):
    print("File exists")
else:
    print("File does not exist, downloading...")
    # !wget http://downloads.metabase.com/v0.46.0/metabase.jar

# run metabase
# !java -jar metabase.jar
# Out:
# [Errno 2] No such file or directory: './metabase'
# /workspace/meta/metabase
# File exists
# Picked up JAVA_TOOL_OPTIONS:  -Xmx12884m
# Warning: environ value /home/gitpod/.sdkman/candidates/java/current for key :java-home has been overwritten with /home/gitpod/.sdkman/candidates/java/11.0.19.fx-zulu
# 2023-05-13 11:18:58,918 INFO metabase.util :: Maximum memory available to JVM: 12.6 GB
# 2023-05-13 11:19:00,249 WARN db.env :: WARNING: Using Metabase with an H2 application database is not recommended for production deployments. For production deployments, we highly recommend using Postgres, MySQL, or MariaDB instead. If you decide to continue to use H2, please be sure to back up the database file regularly. For more information, see https://metabase.com/docs/latest/operations-guide/migrating-from-h2.html
# 2023-05-13 11:19:00,402 INFO util.encryption :: Saved credentials encryption is DISABLED for this Metabase instance. 🔓
#  For more information, see https://metabase.com/docs/latest/operations-guide/encrypting-database-details-at-rest.html
# ..instrumented #'metabase.util.malli/with-api-error-message
# ..instrumented #'metabase.util.honey-sql-2/identifier
# ..instrumented #'metabase.util.honey-sql-2/normalize-type-info
# ..instrumented #'metabase.util.honey-sql-2/with-database-type-info
# ..instrumented #'metabase.util.honey-sql-2/cast
# ..instrumented #'metabase.util.honey-sql-2/quoted-cast
# ..instrumented #'metabase.util.honey-sql-2/maybe-cast
# ..instrumented #'metabase.models.permissions/classify-path
# ..instrumented #'metabase.models.permissions/classify-data-path
# ..instrumented #'metabase.models.permissions/generate-graph
# ..instrumented #'metabase.models.permissions/->v2-path
# ..instrumented #'metabase.models.permissions/update-db-data-access-permissions!
# ..instrumented #'metabase.models.permissions/update-group-permissions!
# ..instrumented #'metabase.models.permissions/update-data-perms-graph!
# ..instrumented #'metabase.models.parameter-card/upsert-or-delete-from-parameters!
# WARNING: abs already refers to: #'clojure.core/abs in namespace: kixi.stats.math, being replaced by: #'kixi.stats.math/abs
# WARNING: abs already refers to: #'clojure.core/abs in namespace: kixi.stats.test, being replaced by: #'kixi.stats.math/abs
# WARNING: abs already refers to: #'clojure.core/abs in namespace: kixi.stats.distribution, being replaced by: #'kixi.stats.math/abs
# ..instrumented #'metabase.query-processor.middleware.permissions/check-query-permissions*
# ..instrumented #'metabase.driver.sql-jdbc.sync.describe-database/simple-select-probe-query
# 2023-05-13 11:19:05,511 INFO driver.impl :: Registered abstract driver :sql  🚚
# 2023-05-13 11:19:05,514 INFO metabase.util ::  ⮦ Load driver :sql took 75.4 ms
# 2023-05-13 11:19:05,518 INFO driver.impl :: Registered abstract driver :sql-jdbc (parents: [:sql]) 🚚
# 2023-05-13 11:19:05,520 INFO metabase.util :: Load driver :sql-jdbc took 84.8 ms
# 2023-05-13 11:19:05,521 INFO driver.impl :: Registered driver :h2 (parents: [:sql-jdbc]) 🚚
# ..instrumented #'metabase.driver.h2/classify-query
# 2023-05-13 11:19:05,559 INFO driver.impl :: Registered driver :mysql (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:19:05,584 INFO driver.impl :: Registered driver :postgres (parents: [:sql-jdbc]) 🚚
# ..instrumented #'metabase.models.params.custom-values/values-from-card
# ..instrumented #'metabase.api.card/param-values
# ..instrumented #'metabase.api.dashboard/chain-filter
# 2023-05-13 11:19:07,100 INFO metabase.core ::
# Metabase v0.46.0 (0ca7df3 release-x.46.x)
#
# Copyright © 2023 Metabase, Inc.
#
# Metabase Enterprise Edition extensions are NOT PRESENT.
# 2023-05-13 11:19:07,108 INFO metabase.core :: Starting Metabase in STANDALONE mode
# 2023-05-13 11:19:07,164 INFO metabase.server :: Launching Embedded Jetty Webserver with config:
#  {:port 3000}
#
# 2023-05-13 11:19:07,218 INFO metabase.core :: Starting Metabase version v0.46.0 (0ca7df3 release-x.46.x) ...
# 2023-05-13 11:19:07,246 INFO metabase.core :: System info:
#  {"file.encoding" "UTF-8",
#  "java.runtime.name" "OpenJDK Runtime Environment",
#  "java.runtime.version" "11.0.19+7-LTS",
#  "java.vendor" "Azul Systems, Inc.",
#  "java.vendor.url" "http://www.azul.com/",
#  "java.version" "11.0.19",
#  "java.vm.name" "OpenJDK 64-Bit Server VM",
#  "java.vm.version" "11.0.19+7-LTS",
#  "os.name" "Linux",
#  "os.version" "6.1.27-060127-generic",
#  "user.language" "en",
#  "user.timezone" "GMT"}
#
# 2023-05-13 11:19:07,248 INFO metabase.plugins :: Loading plugins in /workspace/meta/metabase/plugins...
# 2023-05-13 11:19:07,513 INFO plugins.dependencies :: Plugin 'Metabase BigQuery Driver' depends on plugin 'Metabase Google Drivers Shared Dependencies'
# 2023-05-13 11:19:07,514 INFO plugins.dependencies :: Metabase BigQuery Driver dependency {:plugin Metabase Google Drivers Shared Dependencies} satisfied? false
# 2023-05-13 11:19:07,515 INFO plugins.dependencies :: Plugins with unsatisfied deps: ["Metabase BigQuery Driver"]
# 2023-05-13 11:19:07,520 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :presto...
# 2023-05-13 11:19:07,521 INFO driver.impl :: Registered driver :presto (parents: [:sql]) 🚚
# 2023-05-13 11:19:07,525 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :google...
# 2023-05-13 11:19:07,525 INFO driver.impl :: Registered abstract driver :google  🚚
# 2023-05-13 11:19:07,526 INFO plugins.dependencies :: Metabase BigQuery Driver dependency {:plugin Metabase Google Drivers Shared Dependencies} satisfied? true
# 2023-05-13 11:19:07,526 DEBUG plugins.initialize :: Dependencies satisfied; these plugins will now be loaded: ["Metabase BigQuery Driver"]
# 2023-05-13 11:19:07,527 WARN plugins.lazy-loaded-driver :: Warning: plugin manifest for :bigquery does not include connection properties
# 2023-05-13 11:19:07,527 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :bigquery...
# 2023-05-13 11:19:07,527 INFO driver.impl :: Registered driver :bigquery (parents: [:sql :google]) 🚚
# 2023-05-13 11:19:07,536 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :hive-like...
# 2023-05-13 11:19:07,536 INFO driver.impl :: Registered abstract driver :hive-like (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:19:07,537 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :sparksql...
# 2023-05-13 11:19:07,537 INFO driver.impl :: Registered driver :sparksql (parents: [:hive-like]) 🚚
# 2023-05-13 11:19:07,552 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :athena...
# 2023-05-13 11:19:07,552 INFO driver.impl :: Registered driver :athena (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:19:07,558 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :sqlserver...
# 2023-05-13 11:19:07,559 INFO driver.impl :: Registered driver :sqlserver (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:19:07,571 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :presto-jdbc...
# 2023-05-13 11:19:07,571 INFO driver.impl :: Registered driver :presto-jdbc (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:19:07,574 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :sqlite...
# 2023-05-13 11:19:07,574 INFO driver.impl :: Registered driver :sqlite (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:19:07,577 INFO plugins.dependencies :: Metabase cannot initialize plugin Metabase Vertica Driver due to required dependencies. Metabase requires the Vertica JDBC driver in order to connect to Vertica databases, but we can't ship it as part of Metabase due to licensing restrictions. See https://metabase.com/docs/latest/administration-guide/databases/vertica.html for more details.
#
# 2023-05-13 11:19:07,577 INFO plugins.dependencies :: Metabase Vertica Driver dependency {:class com.vertica.jdbc.Driver} satisfied? false
# 2023-05-13 11:19:07,577 INFO plugins.dependencies :: Plugins with unsatisfied deps: ["Metabase Vertica Driver"]
# 2023-05-13 11:19:07,580 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :redshift...
# 2023-05-13 11:19:07,580 INFO driver.impl :: Registered driver :redshift (parents: [:postgres]) 🚚
# 2023-05-13 11:19:07,583 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :druid...
# 2023-05-13 11:19:07,583 INFO driver.impl :: Registered driver :druid  🚚
# 2023-05-13 11:19:07,588 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :mongo...
# 2023-05-13 11:19:07,588 INFO driver.impl :: Registered driver :mongo  🚚
# 2023-05-13 11:19:07,591 INFO plugins.dependencies :: Metabase cannot initialize plugin Metabase Oracle Driver due to required dependencies. Metabase requires the Oracle JDBC driver in order to connect to Oracle databases, but we can't ship it as part of Metabase due to licensing restrictions. See https://metabase.com/docs/latest/administration-guide/databases/oracle.html for more details.
#
# 2023-05-13 11:19:07,592 INFO plugins.dependencies :: Metabase Oracle Driver dependency {:class oracle.jdbc.OracleDriver} satisfied? false
# 2023-05-13 11:19:07,592 INFO plugins.dependencies :: Plugins with unsatisfied deps: ["Metabase Oracle Driver" "Metabase Vertica Driver"]
# 2023-05-13 11:19:07,607 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :snowflake...
# 2023-05-13 11:19:07,608 INFO driver.impl :: Registered driver :snowflake (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:19:07,611 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :googleanalytics...
# 2023-05-13 11:19:07,611 INFO driver.impl :: Registered driver :googleanalytics  🚚
# 2023-05-13 11:19:07,616 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :bigquery-cloud-sdk...
# 2023-05-13 11:19:07,616 INFO driver.impl :: Registered driver :bigquery-cloud-sdk (parents: [:sql]) 🚚
# 2023-05-13 11:19:07,618 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :csv...
# 2023-05-13 11:19:07,618 INFO driver.impl :: Registered driver :csv (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:19:07,619 INFO metabase.core :: Setting up and migrating Metabase DB. Please sit tight, this may take a minute...
# 2023-05-13 11:19:07,622 INFO db.setup :: Verifying h2 Database Connection ...
# 2023-05-13 11:19:08,089 INFO db.setup :: Successfully verified H2 2.1.212 (2022-04-09) application database connection. ✅
# 2023-05-13 11:19:08,091 INFO db.setup :: Running Database Migrations...
# 2023-05-13 11:19:08,092 INFO db.setup :: Setting up Liquibase...
# 2023-05-13 11:19:08,270 INFO db.setup :: Liquibase is ready.
# 2023-05-13 11:19:08,271 INFO db.liquibase :: Checking if Database has unrun migrations...
# 2023-05-13 11:19:09,354 INFO db.setup :: Database Migrations Current ...  ✅
# 2023-05-13 11:19:09,377 INFO db.data-migrations :: Running all necessary data migrations, this may take a minute.
# 2023-05-13 11:19:09,837 INFO db.data-migrations :: Finished running data migrations.
# 2023-05-13 11:19:09,838 INFO metabase.util :: Database setup took 2.2 s
# 2023-05-13 11:19:09,920 INFO metabase.events :: Starting events listener: :metabase.events.activity-feed/ActivityFeed 👂
# 2023-05-13 11:19:09,925 INFO metabase.events :: Starting events listener: :metabase.events.last-login/LastLogin 👂
# 2023-05-13 11:19:09,925 INFO metabase.events :: Starting events listener: :metabase.events.persisted-info/PersistedInfo 👂
# 2023-05-13 11:19:09,926 INFO metabase.events :: Starting events listener: :metabase.events.sync-database/Sync 👂
# 2023-05-13 11:19:09,927 INFO metabase.events :: Starting events listener: :metabase.events.driver-notifications/DriverNotifications 👂
# 2023-05-13 11:19:09,927 INFO metabase.events :: Starting events listener: :metabase.events.revision/Revisions 👂
# 2023-05-13 11:19:09,928 INFO metabase.events :: Starting events listener: :metabase.events.view-log/ViewLog 👂
# 2023-05-13 11:19:09,968 INFO driver.impl :: Initializing driver :sql...
# 2023-05-13 11:19:09,969 INFO driver.impl :: Initializing driver :sql-jdbc...
# 2023-05-13 11:19:09,969 INFO driver.impl :: Initializing driver :h2...
# 2023-05-13 11:19:10,094 INFO impl.StdSchedulerFactory :: Using default implementation for ThreadExecutor
# 2023-05-13 11:19:10,109 INFO core.SchedulerSignalerImpl :: Initialized Scheduler Signaller of type: class org.quartz.core.SchedulerSignalerImpl
# 2023-05-13 11:19:10,109 INFO core.QuartzScheduler :: Quartz Scheduler v.2.3.2 created.
# 2023-05-13 11:19:10,111 INFO jdbcjobstore.JobStoreTX :: Using db table-based data access locking (synchronization).
# 2023-05-13 11:19:10,113 INFO jdbcjobstore.JobStoreTX :: JobStoreTX initialized.
# 2023-05-13 11:19:10,113 INFO core.QuartzScheduler :: Scheduler meta-data: Quartz Scheduler (v2.3.2) 'MetabaseScheduler' with instanceId 'abdulsaboor938-meta-fqivgh561gb1683976750096'
#   Scheduler class: 'org.quartz.core.QuartzScheduler' - running locally.
#   NOT STARTED.
#   Currently in standby mode.
#   Number of jobs executed: 0
#   Using thread pool 'org.quartz.simpl.SimpleThreadPool' - with 10 threads.
#   Using job-store 'org.quartz.impl.jdbcjobstore.JobStoreTX' - which supports persistence. and is clustered.
#
# 2023-05-13 11:19:10,113 INFO impl.StdSchedulerFactory :: Quartz scheduler 'MetabaseScheduler' initialized from default resource file in Quartz package: 'quartz.properties'
# 2023-05-13 11:19:10,114 INFO impl.StdSchedulerFactory :: Quartz scheduler version: 2.3.2
# 2023-05-13 11:19:10,196 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683976750096 paused.
# 2023-05-13 11:19:10,197 INFO metabase.task :: Task scheduler initialized into standby mode.
# 2023-05-13 11:19:10,198 INFO metabase.task :: Initializing task SyncDatabases 📆
# 2023-05-13 11:19:10,233 INFO task.sync-databases :: Updated default schedules for 0 databases
# 2023-05-13 11:19:10,233 INFO metabase.task :: Initializing task PersistRefresh 📆
# 2023-05-13 11:19:10,242 INFO driver.impl :: Initializing driver :csv...
# 2023-05-13 11:19:10,243 INFO plugins.classloader :: Added URL file:/workspace/meta/metabase/plugins/csv.metabase-driver.jar to classpath
# 2023-05-13 11:19:10,244 DEBUG plugins.init-steps :: Loading plugin namespace metabase.driver.csv...
# 2023-05-13 11:19:10,256 DEBUG plugins.jdbc-proxy :: Registering JDBC proxy driver for org.relique.jdbc.csv.CsvDriver...
# 2023-05-13 11:19:10,257 INFO metabase.util :: Load lazy loading driver :csv took 13.8 ms
# 2023-05-13 11:19:10,268 INFO metabase.task :: Initializing task CheckForNewVersions 📆
# 2023-05-13 11:19:10,286 INFO metabase.task :: Initializing task PersistPrune 📆
# 2023-05-13 11:19:10,289 INFO metabase.task :: Initializing task SendAnonymousUsageStats 📆
# 2023-05-13 11:19:10,300 INFO metabase.task :: Initializing task RefreshSlackChannelsAndUsers 📆
# 2023-05-13 11:19:10,312 INFO metabase.task :: Initializing task SendPulses 📆
# 2023-05-13 11:19:10,318 INFO metabase.task :: Initializing task SendFollowUpEmails 📆
# 2023-05-13 11:19:10,326 INFO metabase.task :: Initializing task TaskHistoryCleanup 📆
# 2023-05-13 11:19:10,333 INFO metabase.task :: Initializing task TruncateAuditLog 📆
# 2023-05-13 11:19:10,341 INFO jdbcjobstore.JobStoreTX :: ClusterManager: detected 1 failed or restarted instances.
# 2023-05-13 11:19:10,342 INFO jdbcjobstore.JobStoreTX :: ClusterManager: Scanning for instance "abdulsaboor938-meta-fqivgh561gb1683976163252"'s failed in-progress jobs.
# 2023-05-13 11:19:10,343 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683976750096 started.
# 2023-05-13 11:19:10,344 INFO metabase.task :: Task scheduler started
# 2023-05-13 11:19:10,345 INFO metabase.core :: Metabase Initialization COMPLETE
# 2023-05-13 11:19:10,359 INFO task.refresh-slack-channel-user-cache :: Slack is not configured, not refreshing slack user/channel cache.
# 2023-05-13 11:19:10,861 INFO i18n.impl :: Reading available locales from locales.clj...
# 2023-05-13 11:19:10,914 INFO util.fonts :: Reading available fonts from /frontend_client/app/fonts
# 2023-05-13 11:19:12,139 DEBUG middleware.log :: GET /api/session/properties 200 46.2 ms (4 DB calls) App DB connections: 1/4 Jetty threads: 7/50 (5 idle, 0 queued) (47 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:12,167 DEBUG middleware.log :: GET /api/user/current 200 76.1 ms (9 DB calls) App DB connections: 0/4 Jetty threads: 6/50 (5 idle, 0 queued) (47 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:12,727 DEBUG middleware.log :: GET /api/database 200 26.7 ms (3 DB calls) App DB connections: 1/7 Jetty threads: 10/50 (0 idle, 0 queued) (47 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:12,729 DEBUG middleware.log :: GET /api/collection/tree 200 27.5 ms (5 DB calls) App DB connections: 1/7 Jetty threads: 10/50 (0 idle, 0 queued) (47 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:12,731 DEBUG middleware.log :: GET /api/bookmark 200 27.5 ms (1 DB calls) App DB connections: 0/7 Jetty threads: 10/50 (0 idle, 0 queued) (48 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:12,741 DEBUG middleware.log :: GET /api/collection/root 200 40.5 ms (2 DB calls) App DB connections: 0/7 Jetty threads: 7/50 (1 idle, 0 queued) (49 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:12,741 DEBUG middleware.log :: GET /api/search 200 39.0 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 7/50 (1 idle, 0 queued) (49 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:13,567 DEBUG middleware.log :: GET /api/timeline 200 8.7 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 8/50 (3 idle, 0 queued) (49 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:13,594 DEBUG middleware.log :: GET /api/database/3/schemas 200 29.1 ms (4 DB calls) App DB connections: 0/7 Jetty threads: 7/50 (3 idle, 0 queued) (49 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:13,661 DEBUG middleware.log :: GET /api/table/5/query_metadata 200 94.8 ms (9 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (49 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:14,332 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:19:14,973 DEBUG middleware.log :: POST /api/dataset 202 [ASYNC: completed] 901.2 ms (24 DB calls) App DB connections: 1/7 Jetty threads: 5/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 0/0 (0 threads blocked)
# 2023-05-13 11:19:48,171 DEBUG middleware.log :: GET /api/session/properties 200 15.2 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 7/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:48,179 DEBUG middleware.log :: GET /api/setting 200 23.1 ms (2 DB calls) App DB connections: 0/7 Jetty threads: 7/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:49,381 DEBUG middleware.log :: GET /api/setup/admin_checklist 200 33.2 ms (13 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:51,924 DEBUG middleware.log :: GET /api/database 200 7.0 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:54,318 DEBUG middleware.log :: GET /api/database/3 200 8.8 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:56,987 DEBUG middleware.log :: GET /api/database/3 200 6.6 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 8/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:56,998 DEBUG middleware.log :: GET /api/database 200 17.4 ms (7 DB calls) App DB connections: 1/7 Jetty threads: 7/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:57,009 DEBUG middleware.log :: GET /api/database/3/metadata 200 28.0 ms (7 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:58,580 DEBUG middleware.log :: GET /api/table/5 200 13.9 ms (5 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:19:58,944 DEBUG middleware.log :: GET /api/database/3/idfields 200 9.5 ms (5 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:20:12,427 DEBUG middleware.log :: PUT /api/field/41 200 21.7 ms (9 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:20:12,883 DEBUG middleware.log :: GET /api/field/41/values 200 7.6 ms (4 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (5 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:20:18,187 DEBUG middleware.log :: PUT /api/field/47 200 17.9 ms (9 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (5 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:20:18,613 DEBUG middleware.log :: GET /api/field/47/values 200 7.1 ms (4 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (5 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:20:22,170 DEBUG middleware.log :: PUT /api/field/42 200 13.0 ms (8 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (5 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:20:22,591 DEBUG middleware.log :: GET /api/field/42/values 200 5.6 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (5 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:20:50,606 DEBUG middleware.log :: GET /api/activity/recent_views 200 22.2 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 9/50 (2 idle, 0 queued) (53 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:20:50,612 DEBUG middleware.log :: GET /api/activity/popular_items 200 28.2 ms (6 DB calls) App DB connections: 0/7 Jetty threads: 8/50 (2 idle, 0 queued) (54 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:20:50,878 DEBUG middleware.log :: GET /api/automagic-dashboards/database/3/candidates 200 294.4 ms (6 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (2 idle, 0 queued) (54 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:20:53,910 DEBUG middleware.log :: GET /api/database/3/schema/PUBLIC 200 11.0 ms (4 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (2 idle, 0 queued) (54 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:20:55,920 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:20:56,348 DEBUG middleware.log :: POST /api/dataset 202 [ASYNC: completed] 467.7 ms (24 DB calls) App DB connections: 1/7 Jetty threads: 5/50 (2 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 0/2 (0 threads blocked)
# 2023-05-13 11:21:05,218 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:21:06,521 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:21:09,612 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:21:24,744 DEBUG middleware.log :: GET /api/field/41/search/41 200 19.6 s (15 DB calls) App DB connections: 0/7 Jetty threads: 7/50 (1 idle, 0 queued) (57 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 0/2 (0 threads blocked)
# 2023-05-13 11:21:24,747 INFO middleware.exceptions :: Request canceled before finishing.
# 2023-05-13 11:21:24,748 DEBUG middleware.log :: GET /api/field/41/search/41 null 19.6 s (15 DB calls) App DB connections: 0/7 Jetty threads: 7/50 (1 idle, 0 queued) (57 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 0/2 (0 threads blocked)
# 2023-05-13 11:21:27,326 DEBUG middleware.log :: POST /api/dataset 202 [ASYNC: completed] 17.8 s (25 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (1 idle, 0 queued) (58 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 2/2 (0 threads blocked)
# 2023-05-13 11:21:27,951 DEBUG middleware.log :: GET /api/field/41/search/41 200 21.5 s (13 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (1 idle, 0 queued) (58 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 1/2 (0 threads blocked)
# 2023-05-13 11:21:44,154 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:21:44,504 DEBUG middleware.log :: POST /api/dataset 202 [ASYNC: completed] 396.6 ms (24 DB calls) App DB connections: 1/7 Jetty threads: 5/50 (1 idle, 0 queued) (60 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 0/3 (0 threads blocked)
# 2023-05-13 11:22:00,692 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:01,010 DEBUG middleware.log :: POST /api/dataset 202 [ASYNC: completed] 363.6 ms (24 DB calls) App DB connections: 1/7 Jetty threads: 5/50 (4 idle, 0 queued) (61 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 0/3 (0 threads blocked)
# 2023-05-13 11:22:08,594 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,594 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,594 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,594 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,594 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,596 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,597 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,675 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,675 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,676 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,677 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,678 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,681 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,681 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,682 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,685 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:08,987 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:09,079 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:09,088 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:09,094 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:09,094 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:09,101 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:09,190 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:09,279 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:14,374 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:14,375 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:14,384 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:14,397 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:18,282 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:18,289 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:18,292 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:18,378 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:18,390 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:18,477 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:18,682 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:18,976 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:18,976 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:18,977 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:18,980 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:18,984 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:18,992 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:19,177 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:19,374 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:19,377 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:22:19,685 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:23:09,774 DEBUG middleware.log :: GET /api/tiles/18/160940/96319/42/47 200 1.0 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 50/50 (0 idle, 40 queued) (98 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 7/9 (3 threads blocked)
# 2023-05-13 11:23:09,794 DEBUG middleware.log :: GET /api/tiles/18/160941/96321/42/47 200 1.0 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 49/50 (0 idle, 41 queued) (99 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 1/3 (0 threads blocked)
# 2023-05-13 11:23:10,118 DEBUG middleware.log :: GET /api/tiles/18/160939/96321/42/47 200 1.0 mins (9 DB calls) App DB connections: 6/15 Jetty threads: 48/50 (0 idle, 42 queued) (100 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 7/7 (1 threads blocked)
# 2023-05-13 11:23:10,626 DEBUG middleware.log :: GET /api/tiles/18/160942/96319/42/47 200 1.0 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 47/50 (0 idle, 43 queued) (101 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 12/12 (0 threads blocked)
# 2023-05-13 11:23:10,792 DEBUG middleware.log :: GET /api/tiles/18/160942/96321/42/47 200 1.0 mins (9 DB calls) App DB connections: 2/15 Jetty threads: 46/50 (0 idle, 44 queued) (102 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 13/13 (0 threads blocked)
# 2023-05-13 11:23:11,105 DEBUG middleware.log :: GET /api/tiles/18/160940/96320/42/47 200 1.0 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 45/50 (0 idle, 45 queued) (103 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 9/9 (2 threads blocked)
# 2023-05-13 11:23:11,181 DEBUG middleware.log :: GET /api/tiles/18/160942/96322/42/47 200 1.0 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 45/50 (0 idle, 43 queued) (105 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 3/3 (0 threads blocked)
# 2023-05-13 11:23:11,182 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:23:11,208 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:23:11,275 DEBUG middleware.log :: GET /api/tiles/18/160939/96319/42/47 200 1.0 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 45/50 (0 idle, 42 queued) (105 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 6/6 (0 threads blocked)
# 2023-05-13 11:23:11,317 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:23:11,407 DEBUG middleware.log :: GET /api/tiles/18/160941/96320/42/47 200 1.0 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 45/50 (0 idle, 42 queued) (106 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 14/14 (0 threads blocked)
# 2023-05-13 11:23:11,422 DEBUG middleware.log :: GET /api/tiles/18/160940/96321/42/47 200 1.0 mins (9 DB calls) App DB connections: 2/15 Jetty threads: 47/50 (0 idle, 36 queued) (107 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 5/5 (0 threads blocked)
# 2023-05-13 11:23:11,511 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:23:11,516 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:23:11,519 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:23:11,519 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:23:11,522 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:23:11,583 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:23:11,682 DEBUG middleware.log :: GET /api/tiles/18/160942/96320/42/47 200 1.1 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 49/50 (0 idle, 37 queued) (108 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 7/7 (0 threads blocked)
# 2023-05-13 11:23:11,726 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:23:11,827 DEBUG middleware.log :: GET /api/tiles/18/160940/96322/42/47 200 1.1 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 49/50 (0 idle, 37 queued) (109 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 0/3 (0 threads blocked)
# 2023-05-13 11:23:11,912 DEBUG middleware.log :: GET /api/tiles/18/160941/96319/42/47 200 1.1 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 48/50 (0 idle, 38 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 4/4 (0 threads blocked)
# 2023-05-13 11:23:12,008 DEBUG middleware.log :: GET /api/tiles/18/160939/96322/42/47 200 1.1 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 48/50 (0 idle, 38 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 2/3 (0 threads blocked)
# 2023-05-13 11:23:12,014 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:23:12,291 DEBUG middleware.log :: GET /api/tiles/18/160939/96320/42/47 200 1.1 mins (9 DB calls) App DB connections: 2/15 Jetty threads: 47/50 (0 idle, 39 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 7/7 (2 threads blocked)
# 2023-05-13 11:23:12,311 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:23:12,311 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:23:12,383 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:24:03,797 DEBUG middleware.log :: GET /api/tiles/18/160941/96322/42/47 200 1.9 mins (10 DB calls) App DB connections: 1/15 Jetty threads: 49/50 (0 idle, 32 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (0 threads blocked)
# 2023-05-13 11:24:03,800 DEBUG middleware.log :: GET /api/tiles/18/160940/96321/42/47 200 1.7 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 48/50 (0 idle, 33 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (28 threads blocked)
# 2023-05-13 11:24:03,815 DEBUG middleware.log :: GET /api/tiles/18/160938/96319/42/47 200 1.7 mins (9 DB calls) App DB connections: 4/15 Jetty threads: 47/50 (0 idle, 34 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (29 threads blocked)
# 2023-05-13 11:24:04,198 DEBUG middleware.log :: GET /api/tiles/18/160943/96321/42/47 200 1.9 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 46/50 (0 idle, 28 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (1 threads blocked)
# 2023-05-13 11:24:04,205 DEBUG middleware.log :: GET /api/tiles/18/160941/96319/42/47 200 1.8 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 45/50 (0 idle, 29 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (27 threads blocked)
# 2023-05-13 11:24:04,275 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:24:04,298 DEBUG middleware.log :: GET /api/tiles/18/160942/96319/42/47 200 53.0 s (9 DB calls) App DB connections: 0/15 Jetty threads: 45/50 (0 idle, 28 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (24 threads blocked)
# 2023-05-13 11:24:04,318 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:24:04,798 DEBUG middleware.log :: GET /api/tiles/18/160943/96319/42/47 200 1.9 mins (9 DB calls) App DB connections: 2/15 Jetty threads: 45/50 (0 idle, 27 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (3 threads blocked)
# 2023-05-13 11:24:04,814 DEBUG middleware.log :: GET /api/tiles/18/160940/96319/42/47 200 1.8 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 45/50 (0 idle, 26 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (18 threads blocked)
# 2023-05-13 11:24:04,818 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:24:04,884 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:24:05,374 DEBUG middleware.log :: GET /api/tiles/18/160938/96321/42/47 200 53.8 s (9 DB calls) App DB connections: 1/15 Jetty threads: 45/50 (0 idle, 26 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (28 threads blocked)
# 2023-05-13 11:24:05,404 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:24:05,816 DEBUG middleware.log :: GET /api/tiles/18/160942/96321/42/47 200 54.7 s (9 DB calls) App DB connections: 2/15 Jetty threads: 45/50 (0 idle, 26 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (22 threads blocked)
# 2023-05-13 11:24:05,884 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:24:06,208 DEBUG middleware.log :: GET /api/tiles/18/160938/96322/42/47 200 2.0 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 45/50 (0 idle, 26 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (2 threads blocked)
# 2023-05-13 11:24:06,278 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:24:06,423 DEBUG middleware.log :: GET /api/tiles/18/160943/96321/42/47 200 55.2 s (9 DB calls) App DB connections: 7/15 Jetty threads: 45/50 (0 idle, 26 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (23 threads blocked)
# 2023-05-13 11:24:06,497 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:24:06,588 DEBUG middleware.log :: GET /api/tiles/18/160942/96322/42/47 200 54.9 s (9 DB calls) App DB connections: 0/15 Jetty threads: 45/50 (0 idle, 26 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (28 threads blocked)
# 2023-05-13 11:24:06,695 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:24:06,908 DEBUG middleware.log :: GET /api/tiles/18/160939/96320/42/47 200 55.5 s (9 DB calls) App DB connections: 1/15 Jetty threads: 45/50 (0 idle, 26 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (27 threads blocked)
# 2023-05-13 11:24:06,925 DEBUG middleware.log :: GET /api/tiles/18/160943/96320/42/47 200 1.8 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 45/50 (0 idle, 26 queued) (110 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (17 threads blocked)
# 2023-05-13 11:24:06,976 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:24:07,004 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:24:12,392 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:25:03,823 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:25:03,824 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:25:03,882 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:25:04,219 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# ...
#     "query_processor$process_userland_query.doInvoke(query_processor.clj:358)"
#     "query_processor$fn__70735$process_query_and_save_execution_BANG___70744$fn__70747.invoke(query_processor.clj:373)"
#     "query_processor$fn__70735$process_query_and_save_execution_BANG___70744.invoke(query_processor.clj:366)"
#     "query_processor$fn__70780$process_query_and_save_with_max_results_constraints_BANG___70789$fn__70792.invoke(query_processor.clj:385)"
#     "query_processor$fn__70780$process_query_and_save_with_max_results_constraints_BANG___70789.invoke(query_processor.clj:378)"
#     "api.dataset$run_query_async$fn__86532.invoke(dataset.clj:73)"
#     "query_processor.streaming$streaming_response_STAR_$fn__54305$fn__54306.invoke(streaming.clj:166)"
#     "query_processor.streaming$streaming_response_STAR_$fn__54305.invoke(streaming.clj:165)"
#     "async.streaming_response$do_f_STAR_.invokeStatic(streaming_response.clj:69)"
#     "async.streaming_response$do_f_STAR_.invoke(streaming_response.clj:67)"
#     "async.streaming_response$do_f_async$task__36922.invoke(streaming_response.clj:88)"],
#    :error_type :invalid-query,
#    :ex-data
#    {:driver :csv,
#     :sql
#     ["-- Metabase:: userID: 1 queryType: MBQL queryHash: 7486352d243fa9f3c5b9ec98fdf5d9ee555cd877aad826be8c684df84f357040"
#      "SELECT"
#      "  \"PUBLIC\".\"final_data\".\"date\" AS \"date\","
#      "  count(*) AS \"count\""
#      "FROM"
#      "  \"PUBLIC\".\"final_data\""
#      "GROUP BY"
#      "  \"PUBLIC\".\"final_data\".\"date\""
#      "ORDER BY"
#      "  \"PUBLIC\".\"final_data\".\"date\" ASC"],
#     :params nil,
#     :type :invalid-query}}],
#  :state nil,
#  :error_type :invalid-query,
#  :json_query
#  {:type "query",
#   :database 3,
#   :query {:source-table 5, :breakout [["field" 43 nil]], :aggregation [["count"]]},
#   :parameters [],
#   :middleware {:js-int-to-string? true, :add-default-userland-constraints? true}},
#  :native
#  {:query
#   "SELECT \"PUBLIC\".\"final_data\".\"date\" AS \"date\", count(*) AS \"count\" FROM \"PUBLIC\".\"final_data\" GROUP BY \"PUBLIC\".\"final_data\".\"date\" ORDER BY \"PUBLIC\".\"final_data\".\"date\" ASC",
#   :params nil},
#  :status :failed,
#  :class java.sql.SQLException,
#  :stacktrace
#  ["org.relique.jdbc.csv.CsvStatement.execute(CsvStatement.java:626)"
#   "com.mchange.v2.c3p0.impl.NewProxyStatement.execute(NewProxyStatement.java:75)"
#   "--> driver.sql_jdbc.execute$fn__71708.invokeStatic(execute.clj:384)"
#   "driver.sql_jdbc.execute$fn__71708.invoke(execute.clj:382)"
#   "driver.sql_jdbc.execute$execute_statement_or_prepared_statement_BANG_.invokeStatic(execute.clj:392)"
#   "driver.sql_jdbc.execute$execute_statement_or_prepared_statement_BANG_.invoke(execute.clj:389)"
#   "driver.sql_jdbc.execute$execute_reducible_query$fn__71783.invoke(execute.clj:503)"
#   "driver.sql_jdbc.execute$execute_reducible_query.invokeStatic(execute.clj:502)"
#   "driver.sql_jdbc.execute$execute_reducible_query.invoke(execute.clj:489)"
#   "driver.sql_jdbc.execute$execute_reducible_query.invokeStatic(execute.clj:497)"
#   "driver.sql_jdbc.execute$execute_reducible_query.invoke(execute.clj:489)"
#   "driver.sql_jdbc$fn__105074.invokeStatic(sql_jdbc.clj:63)"
#   "driver.sql_jdbc$fn__105074.invoke(sql_jdbc.clj:61)"
#   "query_processor.context$executef.invokeStatic(context.clj:60)"
#   "query_processor.context$executef.invoke(context.clj:49)"
#   "query_processor.context.default$default_runf.invokeStatic(default.clj:68)"
#   "query_processor.context.default$default_runf.invoke(default.clj:66)"
#   "query_processor.context$runf.invokeStatic(context.clj:46)"
#   "query_processor.context$runf.invoke(context.clj:40)"
#   "query_processor.reducible$identity_qp.invokeStatic(reducible.clj:15)"
#   "query_processor.reducible$identity_qp.invoke(reducible.clj:12)"
#   "query_processor.middleware.cache$maybe_return_cached_results$maybe_return_cached_results_STAR___69168.invoke(cache.clj:224)"
#   "query_processor.middleware.permissions$check_query_permissions$fn__64640.invoke(permissions.clj:126)"
#   "query_processor.middleware.mbql_to_native$mbql__GT_native$fn__68059.invoke(mbql_to_native.clj:24)"
#   "query_processor$fn__70687$combined_post_process__70692$combined_post_process_STAR___70693.invoke(query_processor.clj:243)"
#   "query_processor$fn__70687$combined_pre_process__70688$combined_pre_process_STAR___70689.invoke(query_processor.clj:240)"
#   "query_processor.middleware.resolve_database_and_driver$resolve_database_and_driver$fn__69079$fn__69084.invoke(resolve_database_and_driver.clj:36)"
#   "driver$do_with_driver.invokeStatic(driver.clj:90)"
#   "driver$do_with_driver.invoke(driver.clj:86)"
#   "query_processor.middleware.resolve_database_and_driver$resolve_database_and_driver$fn__69079.invoke(resolve_database_and_driver.clj:35)"
#   "query_processor.middleware.fetch_source_query$resolve_card_id_source_tables$fn__64949.invoke(fetch_source_query.clj:310)"
#   "query_processor.middleware.store$initialize_store$fn__65127$fn__65128.invoke(store.clj:12)"
#   "query_processor.store$do_with_store.invokeStatic(store.clj:47)"
#   "query_processor.store$do_with_store.invoke(store.clj:41)"
#   "query_processor.middleware.store$initialize_store$fn__65127.invoke(store.clj:11)"
#   "query_processor.middleware.normalize_query$normalize$fn__69368.invoke(normalize_query.clj:25)"
#   "query_processor.middleware.constraints$add_default_userland_constraints$fn__66305.invoke(constraints.clj:54)"
#   "query_processor.middleware.process_userland_query$process_userland_query$fn__69304.invoke(process_userland_query.clj:150)"
#   "query_processor.middleware.catch_exceptions$catch_exceptions$fn__69681.invoke(catch_exceptions.clj:171)"
#   "query_processor.reducible$async_qp$qp_STAR___59455$thunk__59457.invoke(reducible.clj:103)"
#   "query_processor.reducible$async_qp$qp_STAR___59455.invoke(reducible.clj:109)"
#   "query_processor.reducible$async_qp$qp_STAR___59455.invoke(reducible.clj:94)"
#   "query_processor.reducible$sync_qp$qp_STAR___59467.doInvoke(reducible.clj:129)"
#   "query_processor$process_userland_query.invokeStatic(query_processor.clj:362)"
#   "query_processor$process_userland_query.doInvoke(query_processor.clj:358)"
#   "query_processor$fn__70735$process_query_and_save_execution_BANG___70744$fn__70747.invoke(query_processor.clj:373)"
#   "query_processor$fn__70735$process_query_and_save_execution_BANG___70744.invoke(query_processor.clj:366)"
#   "query_processor$fn__70780$process_query_and_save_with_max_results_constraints_BANG___70789$fn__70792.invoke(query_processor.clj:385)"
#   "query_processor$fn__70780$process_query_and_save_with_max_results_constraints_BANG___70789.invoke(query_processor.clj:378)"
#   "api.dataset$run_query_async$fn__86532.invoke(dataset.clj:73)"
#   "query_processor.streaming$streaming_response_STAR_$fn__54305$fn__54306.invoke(streaming.clj:166)"
#   "query_processor.streaming$streaming_response_STAR_$fn__54305.invoke(streaming.clj:165)"
#   "async.streaming_response$do_f_STAR_.invokeStatic(streaming_response.clj:69)"
#   "async.streaming_response$do_f_STAR_.invoke(streaming_response.clj:67)"
#   "async.streaming_response$do_f_async$task__36922.invoke(streaming_response.clj:88)"],
#  :card_id nil,
#  :context :ad-hoc,
#  :error "Syntax error: Statement cancelled",
#  :row_count 0,
#  :running_time 0,
#  :preprocessed
#  {:type :query,
#   :database 3,
#   :query
#   {:source-table 5,
#    :breakout [[:field 43 nil]],
#    :aggregation [[:aggregation-options [:count] {:name "count"}]],
#    :order-by [[:asc [:field 43 nil]]]},
#   :middleware {:js-int-to-string? true, :add-default-userland-constraints? true},
#   :info {:executed-by 1, :context :ad-hoc}},
#  :data {:rows [], :cols []}}
#
# 2023-05-13 11:26:16,084 DEBUG middleware.log :: POST /api/dataset 202 [ASYNC: canceled] 54.8 s (12 DB calls) App DB connections: 0/15 Jetty threads: 28/50 (17 idle, 0 queued) (132 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (21 threads blocked)
# 2023-05-13 11:26:16,399 DEBUG middleware.log :: GET /api/tiles/18/160944/96319/42/47 200 4.0 mins (9 DB calls) App DB connections: 4/15 Jetty threads: 27/50 (18 idle, 0 queued) (132 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (25 threads blocked)
# 2023-05-13 11:26:16,400 DEBUG middleware.log :: POST /api/dataset 202 [ASYNC: completed] 1.7 s (24 DB calls) App DB connections: 1/15 Jetty threads: 27/50 (18 idle, 0 queued) (132 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (15 threads blocked)
# 2023-05-13 11:26:16,604 DEBUG middleware.log :: GET /api/tiles/18/160943/96321/42/47 200 1.2 mins (9 DB calls) App DB connections: 2/15 Jetty threads: 26/50 (19 idle, 0 queued) (132 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (26 threads blocked)
# 2023-05-13 11:26:22,513 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:26:24,526 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:27:06,903 DEBUG middleware.log :: GET /api/tiles/18/160939/96321/42/47 200 3.0 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 26/50 (20 idle, 0 queued) (132 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (23 threads blocked)
# 2023-05-13 11:27:07,415 DEBUG middleware.log :: GET /api/tiles/18/160940/96321/42/47 200 3.0 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 25/50 (20 idle, 0 queued) (131 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (23 threads blocked)
# 2023-05-13 11:27:07,683 DEBUG middleware.log :: GET /api/tiles/18/160939/96319/42/47 200 4.8 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 24/50 (21 idle, 0 queued) (131 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (22 threads blocked)
# 2023-05-13 11:27:07,809 DEBUG middleware.log :: GET /api/tiles/18/160941/96321/42/47 200 3.1 mins (9 DB calls) App DB connections: 2/15 Jetty threads: 23/50 (21 idle, 0 queued) (131 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (23 threads blocked)
# 2023-05-13 11:27:07,985 DEBUG middleware.log :: GET /api/tiles/18/160938/96319/42/47 200 5.0 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 22/50 (22 idle, 0 queued) (131 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (7 threads blocked)
# 2023-05-13 11:27:08,213 DEBUG middleware.log :: GET /api/tiles/18/160941/96322/42/47 200 3.0 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 21/50 (23 idle, 0 queued) (131 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (24 threads blocked)
# 2023-05-13 11:27:08,490 DEBUG middleware.log :: GET /api/tiles/18/160939/96322/42/47 200 2.9 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 20/50 (24 idle, 0 queued) (131 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (25 threads blocked)
# 2023-05-13 11:27:09,104 DEBUG middleware.log :: GET /api/tiles/18/160944/96319/42/47 200 4.9 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 19/50 (25 idle, 0 queued) (131 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (10 threads blocked)
# 2023-05-13 11:27:09,291 DEBUG middleware.log :: GET /api/tiles/18/160942/96320/42/47 200 3.1 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 18/50 (26 idle, 0 queued) (131 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (23 threads blocked)
# 2023-05-13 11:27:09,398 DEBUG middleware.log :: GET /api/tiles/18/160944/96320/42/47 200 4.9 mins (9 DB calls) App DB connections: 2/15 Jetty threads: 17/50 (27 idle, 0 queued) (131 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (11 threads blocked)
# 2023-05-13 11:27:09,480 DEBUG middleware.log :: GET /api/tiles/18/160944/96321/42/47 200 4.9 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 16/50 (28 idle, 0 queued) (131 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (9 threads blocked)
# 2023-05-13 11:27:09,912 DEBUG middleware.log :: GET /api/tiles/18/160944/96321/42/47 200 4.9 mins (9 DB calls) App DB connections: 2/15 Jetty threads: 15/50 (29 idle, 0 queued) (131 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (23 threads blocked)
# 2023-05-13 11:27:09,979 DEBUG middleware.log :: GET /api/tiles/18/160938/96321/42/47 200 5.0 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 14/50 (30 idle, 0 queued) (131 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (6 threads blocked)
# 2023-05-13 11:27:10,101 DEBUG middleware.log :: GET /api/tiles/18/160938/96322/42/47 200 4.9 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 13/50 (31 idle, 0 queued) (131 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (24 threads blocked)
# 2023-05-13 11:27:10,217 DEBUG middleware.log :: GET /api/tiles/18/160943/96322/42/47 200 5.0 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 12/50 (32 idle, 0 queued) (131 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (8 threads blocked)
# 2023-05-13 11:27:25,927 DEBUG middleware.log :: GET /api/tiles/18/160943/96319/42/47 200 5.1 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 11/50 (36 idle, 0 queued) (122 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (19 threads blocked)
# 2023-05-13 11:27:26,212 DEBUG middleware.log :: GET /api/tiles/18/160942/96320/42/47 200 5.1 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 10/50 (37 idle, 0 queued) (122 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (21 threads blocked)
# 2023-05-13 11:27:26,471 DEBUG middleware.log :: GET /api/tiles/18/160939/96322/42/47 200 5.1 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 9/50 (37 idle, 0 queued) (122 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (20 threads blocked)
# 2023-05-13 11:27:26,537 DEBUG middleware.log :: GET /api/tiles/18/160938/96320/42/47 200 5.3 mins (9 DB calls) App DB connections: 1/15 Jetty threads: 8/50 (37 idle, 0 queued) (122 total active threads) Queries in flight: 1 (0 queued); csv DB 3 connections: 15/15 (5 threads blocked)
# 2023-05-13 11:27:26,594 DEBUG middleware.log :: POST /api/dataset 202 [ASYNC: completed] 1.0 mins (25 DB calls) App DB connections: 1/15 Jetty threads: 7/50 (37 idle, 0 queued) (122 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (6 threads blocked)
# 2023-05-13 11:27:27,126 DEBUG middleware.log :: GET /api/tiles/18/160943/96320/42/47 200 5.3 mins (9 DB calls) App DB connections: 0/15 Jetty threads: 7/50 (37 idle, 0 queued) (122 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (4 threads blocked)
# 2023-05-13 11:27:28,513 DEBUG middleware.log :: GET /api/field/41/search/41 200 1.1 mins (14 DB calls) App DB connections: 0/15 Jetty threads: 6/50 (38 idle, 0 queued) (124 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 15/15 (5 threads blocked)
# ^C
# 2023-05-13 11:30:51,662 INFO metabase.core :: Metabase Shutting Down ...
# 2023-05-13 11:30:51,663 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683976750096 shutting down.
# 2023-05-13 11:30:51,663 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683976750096 paused.
# 2023-05-13 11:30:51,664 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683976750096 shutdown complete.
# 2023-05-13 11:30:51,664 INFO metabase.server :: Shutting Down Embedded Jetty Webserver
# 2023-05-13 11:30:51,670 INFO metabase.core :: Metabase Shutdown COMPLETE
