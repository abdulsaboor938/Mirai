# %%
# !pip install pandas
# !pip install numpy
import pandas as pd
import numpy as np
# Fuction
def combine_predictions(zone):

    temp = pd.read_csv(f'raw_data/{zone}.csv')

    temp['pred_temp'] = np.nan
    temp['pred_pm25'] = np.nan
    temp['pred_pm10'] = np.nan
    temp['pred_smog'] = np.nan

    temp1 = pd.read_csv(f'prediction/{zone}.csv')
    temp1.columns = ['date','zone','longitude','latitude','pred_temp','pred_pm25','pred_pm10','pred_smog']

    temp1['temperature'] = np.nan
    temp1['pm2_5']=np.nan
    temp1['pm10']=np.nan
    temp1['smog']=np.nan

    temp1=temp1[['date','zone','longitude','latitude','temperature','pm2_5','pm10','smog','pred_temp','pred_pm25','pred_pm10','pred_smog']]

    return(pd.concat([temp,temp1]))

# check if final_data.csv exists
import os.path
from os import path
if path.exists("final_data.csv"):
    print("final_data.csv exists")
else:
    # Writing back to files
    df = combine_predictions(1)
    df.to_csv('final_data.csv', index=False)

    for i in range(2,249):
        combine_predictions(i).to_csv('final_data.csv', mode='a', header=False, index=False)
        print(f"{i} done")
# Out:
# Requirement already satisfied: pandas in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: numpy in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (1.24.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# final_data.csv exists

# %%
# # metabase operations

# going to metabase folder
# %cd ./metabase

# check if metabase.jar is present, if not download it
import os.path
from os import path
if path.exists("metabase.jar"):
    print("File exists")
else:
    print("File does not exist, downloading...")
    # !wget http://downloads.metabase.com/v0.46.0/metabase.jar

# run metabase
# !java -jar metabase.jar
# Out:
# [Errno 2] No such file or directory: './metabase'
# /workspace/meta/metabase
# File exists
# Picked up JAVA_TOOL_OPTIONS:  -Xmx12884m
# Warning: environ value /home/gitpod/.sdkman/candidates/java/current for key :java-home has been overwritten with /home/gitpod/.sdkman/candidates/java/11.0.19.fx-zulu
# 2023-05-13 11:09:12,100 INFO metabase.util :: Maximum memory available to JVM: 12.6 GB
# 2023-05-13 11:09:13,360 WARN db.env :: WARNING: Using Metabase with an H2 application database is not recommended for production deployments. For production deployments, we highly recommend using Postgres, MySQL, or MariaDB instead. If you decide to continue to use H2, please be sure to back up the database file regularly. For more information, see https://metabase.com/docs/latest/operations-guide/migrating-from-h2.html
# 2023-05-13 11:09:13,501 INFO util.encryption :: Saved credentials encryption is DISABLED for this Metabase instance. 🔓
#  For more information, see https://metabase.com/docs/latest/operations-guide/encrypting-database-details-at-rest.html
# ..instrumented #'metabase.util.malli/with-api-error-message
# ..instrumented #'metabase.util.honey-sql-2/identifier
# ..instrumented #'metabase.util.honey-sql-2/normalize-type-info
# ..instrumented #'metabase.util.honey-sql-2/with-database-type-info
# ..instrumented #'metabase.util.honey-sql-2/cast
# ..instrumented #'metabase.util.honey-sql-2/quoted-cast
# ..instrumented #'metabase.util.honey-sql-2/maybe-cast
# ..instrumented #'metabase.models.permissions/classify-path
# ..instrumented #'metabase.models.permissions/classify-data-path
# ..instrumented #'metabase.models.permissions/generate-graph
# ..instrumented #'metabase.models.permissions/->v2-path
# ..instrumented #'metabase.models.permissions/update-db-data-access-permissions!
# ..instrumented #'metabase.models.permissions/update-group-permissions!
# ..instrumented #'metabase.models.permissions/update-data-perms-graph!
# ..instrumented #'metabase.models.parameter-card/upsert-or-delete-from-parameters!
# WARNING: abs already refers to: #'clojure.core/abs in namespace: kixi.stats.math, being replaced by: #'kixi.stats.math/abs
# WARNING: abs already refers to: #'clojure.core/abs in namespace: kixi.stats.test, being replaced by: #'kixi.stats.math/abs
# WARNING: abs already refers to: #'clojure.core/abs in namespace: kixi.stats.distribution, being replaced by: #'kixi.stats.math/abs
# ..instrumented #'metabase.query-processor.middleware.permissions/check-query-permissions*
# ..instrumented #'metabase.driver.sql-jdbc.sync.describe-database/simple-select-probe-query
# 2023-05-13 11:09:18,278 INFO driver.impl :: Registered abstract driver :sql  🚚
# 2023-05-13 11:09:18,281 INFO metabase.util ::  ⮦ Load driver :sql took 71.6 ms
# 2023-05-13 11:09:18,284 INFO driver.impl :: Registered abstract driver :sql-jdbc (parents: [:sql]) 🚚
# 2023-05-13 11:09:18,287 INFO metabase.util :: Load driver :sql-jdbc took 79.9 ms
# 2023-05-13 11:09:18,287 INFO driver.impl :: Registered driver :h2 (parents: [:sql-jdbc]) 🚚
# ..instrumented #'metabase.driver.h2/classify-query
# 2023-05-13 11:09:18,322 INFO driver.impl :: Registered driver :mysql (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:09:18,346 INFO driver.impl :: Registered driver :postgres (parents: [:sql-jdbc]) 🚚
# ..instrumented #'metabase.models.params.custom-values/values-from-card
# ..instrumented #'metabase.api.card/param-values
# ..instrumented #'metabase.api.dashboard/chain-filter
# 2023-05-13 11:09:19,721 INFO metabase.core ::
# Metabase v0.46.0 (0ca7df3 release-x.46.x)
#
# Copyright © 2023 Metabase, Inc.
#
# Metabase Enterprise Edition extensions are NOT PRESENT.
# 2023-05-13 11:09:19,729 INFO metabase.core :: Starting Metabase in STANDALONE mode
# 2023-05-13 11:09:19,774 INFO metabase.server :: Launching Embedded Jetty Webserver with config:
#  {:port 3000}
#
# 2023-05-13 11:09:19,819 INFO metabase.core :: Starting Metabase version v0.46.0 (0ca7df3 release-x.46.x) ...
# 2023-05-13 11:09:19,848 INFO metabase.core :: System info:
#  {"file.encoding" "UTF-8",
#  "java.runtime.name" "OpenJDK Runtime Environment",
#  "java.runtime.version" "11.0.19+7-LTS",
#  "java.vendor" "Azul Systems, Inc.",
#  "java.vendor.url" "http://www.azul.com/",
#  "java.version" "11.0.19",
#  "java.vm.name" "OpenJDK 64-Bit Server VM",
#  "java.vm.version" "11.0.19+7-LTS",
#  "os.name" "Linux",
#  "os.version" "6.1.27-060127-generic",
#  "user.language" "en",
#  "user.timezone" "GMT"}
#
# 2023-05-13 11:09:19,850 INFO metabase.plugins :: Loading plugins in /workspace/meta/metabase/plugins...
# 2023-05-13 11:09:20,122 INFO plugins.dependencies :: Plugin 'Metabase BigQuery Driver' depends on plugin 'Metabase Google Drivers Shared Dependencies'
# 2023-05-13 11:09:20,123 INFO plugins.dependencies :: Metabase BigQuery Driver dependency {:plugin Metabase Google Drivers Shared Dependencies} satisfied? false
# 2023-05-13 11:09:20,124 INFO plugins.dependencies :: Plugins with unsatisfied deps: ["Metabase BigQuery Driver"]
# 2023-05-13 11:09:20,128 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :presto...
# 2023-05-13 11:09:20,128 INFO driver.impl :: Registered driver :presto (parents: [:sql]) 🚚
# 2023-05-13 11:09:20,132 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :google...
# 2023-05-13 11:09:20,132 INFO driver.impl :: Registered abstract driver :google  🚚
# 2023-05-13 11:09:20,132 INFO plugins.dependencies :: Metabase BigQuery Driver dependency {:plugin Metabase Google Drivers Shared Dependencies} satisfied? true
# 2023-05-13 11:09:20,133 DEBUG plugins.initialize :: Dependencies satisfied; these plugins will now be loaded: ["Metabase BigQuery Driver"]
# 2023-05-13 11:09:20,133 WARN plugins.lazy-loaded-driver :: Warning: plugin manifest for :bigquery does not include connection properties
# 2023-05-13 11:09:20,133 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :bigquery...
# 2023-05-13 11:09:20,133 INFO driver.impl :: Registered driver :bigquery (parents: [:sql :google]) 🚚
# 2023-05-13 11:09:20,142 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :hive-like...
# 2023-05-13 11:09:20,142 INFO driver.impl :: Registered abstract driver :hive-like (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:09:20,143 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :sparksql...
# 2023-05-13 11:09:20,143 INFO driver.impl :: Registered driver :sparksql (parents: [:hive-like]) 🚚
# 2023-05-13 11:09:20,179 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :athena...
# 2023-05-13 11:09:20,180 INFO driver.impl :: Registered driver :athena (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:09:20,184 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :sqlserver...
# 2023-05-13 11:09:20,185 INFO driver.impl :: Registered driver :sqlserver (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:09:20,198 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :presto-jdbc...
# 2023-05-13 11:09:20,198 INFO driver.impl :: Registered driver :presto-jdbc (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:09:20,201 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :sqlite...
# 2023-05-13 11:09:20,201 INFO driver.impl :: Registered driver :sqlite (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:09:20,203 INFO plugins.dependencies :: Metabase cannot initialize plugin Metabase Vertica Driver due to required dependencies. Metabase requires the Vertica JDBC driver in order to connect to Vertica databases, but we can't ship it as part of Metabase due to licensing restrictions. See https://metabase.com/docs/latest/administration-guide/databases/vertica.html for more details.
#
# 2023-05-13 11:09:20,204 INFO plugins.dependencies :: Metabase Vertica Driver dependency {:class com.vertica.jdbc.Driver} satisfied? false
# 2023-05-13 11:09:20,204 INFO plugins.dependencies :: Plugins with unsatisfied deps: ["Metabase Vertica Driver"]
# 2023-05-13 11:09:20,207 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :redshift...
# 2023-05-13 11:09:20,207 INFO driver.impl :: Registered driver :redshift (parents: [:postgres]) 🚚
# 2023-05-13 11:09:20,209 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :druid...
# 2023-05-13 11:09:20,209 INFO driver.impl :: Registered driver :druid  🚚
# 2023-05-13 11:09:20,279 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :mongo...
# 2023-05-13 11:09:20,279 INFO driver.impl :: Registered driver :mongo  🚚
# 2023-05-13 11:09:20,283 INFO plugins.dependencies :: Metabase cannot initialize plugin Metabase Oracle Driver due to required dependencies. Metabase requires the Oracle JDBC driver in order to connect to Oracle databases, but we can't ship it as part of Metabase due to licensing restrictions. See https://metabase.com/docs/latest/administration-guide/databases/oracle.html for more details.
#
# 2023-05-13 11:09:20,283 INFO plugins.dependencies :: Metabase Oracle Driver dependency {:class oracle.jdbc.OracleDriver} satisfied? false
# 2023-05-13 11:09:20,284 INFO plugins.dependencies :: Plugins with unsatisfied deps: ["Metabase Oracle Driver" "Metabase Vertica Driver"]
# 2023-05-13 11:09:20,299 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :snowflake...
# 2023-05-13 11:09:20,299 INFO driver.impl :: Registered driver :snowflake (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:09:20,303 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :googleanalytics...
# 2023-05-13 11:09:20,303 INFO driver.impl :: Registered driver :googleanalytics  🚚
# 2023-05-13 11:09:20,308 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :bigquery-cloud-sdk...
# 2023-05-13 11:09:20,308 INFO driver.impl :: Registered driver :bigquery-cloud-sdk (parents: [:sql]) 🚚
# 2023-05-13 11:09:20,310 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :csv...
# 2023-05-13 11:09:20,310 INFO driver.impl :: Registered driver :csv (parents: [:sql-jdbc]) 🚚
# 2023-05-13 11:09:20,311 INFO metabase.core :: Setting up and migrating Metabase DB. Please sit tight, this may take a minute...
# 2023-05-13 11:09:20,314 INFO db.setup :: Verifying h2 Database Connection ...
# 2023-05-13 11:09:21,117 INFO db.setup :: Successfully verified H2 2.1.212 (2022-04-09) application database connection. ✅
# 2023-05-13 11:09:21,119 INFO db.setup :: Running Database Migrations...
# 2023-05-13 11:09:21,121 INFO db.setup :: Setting up Liquibase...
# 2023-05-13 11:09:21,318 INFO db.setup :: Liquibase is ready.
# 2023-05-13 11:09:21,319 INFO db.liquibase :: Checking if Database has unrun migrations...
# 2023-05-13 11:09:22,408 INFO db.setup :: Database Migrations Current ...  ✅
# 2023-05-13 11:09:22,426 INFO db.data-migrations :: Running all necessary data migrations, this may take a minute.
# 2023-05-13 11:09:22,944 INFO db.data-migrations :: Finished running data migrations.
# 2023-05-13 11:09:22,945 INFO metabase.util :: Database setup took 2.6 s
# 2023-05-13 11:09:23,022 INFO metabase.events :: Starting events listener: :metabase.events.activity-feed/ActivityFeed 👂
# 2023-05-13 11:09:23,027 INFO metabase.events :: Starting events listener: :metabase.events.last-login/LastLogin 👂
# 2023-05-13 11:09:23,027 INFO metabase.events :: Starting events listener: :metabase.events.persisted-info/PersistedInfo 👂
# 2023-05-13 11:09:23,028 INFO metabase.events :: Starting events listener: :metabase.events.sync-database/Sync 👂
# 2023-05-13 11:09:23,028 INFO metabase.events :: Starting events listener: :metabase.events.driver-notifications/DriverNotifications 👂
# 2023-05-13 11:09:23,028 INFO metabase.events :: Starting events listener: :metabase.events.revision/Revisions 👂
# 2023-05-13 11:09:23,029 INFO metabase.events :: Starting events listener: :metabase.events.view-log/ViewLog 👂
# 2023-05-13 11:09:23,069 INFO driver.impl :: Initializing driver :sql...
# 2023-05-13 11:09:23,069 INFO driver.impl :: Initializing driver :sql-jdbc...
# 2023-05-13 11:09:23,070 INFO driver.impl :: Initializing driver :h2...
# 2023-05-13 11:09:23,159 INFO util.files :: Extract file /sample-database.db.mv.db -> /workspace/meta/metabase/plugins/sample-database.db.mv.db
# 2023-05-13 11:09:23,251 INFO impl.StdSchedulerFactory :: Using default implementation for ThreadExecutor
# 2023-05-13 11:09:23,261 INFO core.SchedulerSignalerImpl :: Initialized Scheduler Signaller of type: class org.quartz.core.SchedulerSignalerImpl
# 2023-05-13 11:09:23,261 INFO core.QuartzScheduler :: Quartz Scheduler v.2.3.2 created.
# 2023-05-13 11:09:23,262 INFO jdbcjobstore.JobStoreTX :: Using db table-based data access locking (synchronization).
# 2023-05-13 11:09:23,263 INFO jdbcjobstore.JobStoreTX :: JobStoreTX initialized.
# 2023-05-13 11:09:23,264 INFO core.QuartzScheduler :: Scheduler meta-data: Quartz Scheduler (v2.3.2) 'MetabaseScheduler' with instanceId 'abdulsaboor938-meta-fqivgh561gb1683976163252'
#   Scheduler class: 'org.quartz.core.QuartzScheduler' - running locally.
#   NOT STARTED.
#   Currently in standby mode.
#   Number of jobs executed: 0
#   Using thread pool 'org.quartz.simpl.SimpleThreadPool' - with 10 threads.
#   Using job-store 'org.quartz.impl.jdbcjobstore.JobStoreTX' - which supports persistence. and is clustered.
#
# 2023-05-13 11:09:23,264 INFO impl.StdSchedulerFactory :: Quartz scheduler 'MetabaseScheduler' initialized from default resource file in Quartz package: 'quartz.properties'
# 2023-05-13 11:09:23,264 INFO impl.StdSchedulerFactory :: Quartz scheduler version: 2.3.2
# 2023-05-13 11:09:23,340 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683976163252 paused.
# 2023-05-13 11:09:23,340 INFO metabase.task :: Task scheduler initialized into standby mode.
# 2023-05-13 11:09:23,341 INFO metabase.task :: Initializing task SyncDatabases 📆
# 2023-05-13 11:09:23,372 INFO task.sync-databases :: Updated default schedules for 0 databases
# 2023-05-13 11:09:23,372 INFO metabase.task :: Initializing task PersistRefresh 📆
# 2023-05-13 11:09:23,381 INFO driver.impl :: Initializing driver :csv...
# 2023-05-13 11:09:23,381 INFO plugins.classloader :: Added URL file:/workspace/meta/metabase/plugins/csv.metabase-driver.jar to classpath
# 2023-05-13 11:09:23,382 DEBUG plugins.init-steps :: Loading plugin namespace metabase.driver.csv...
# 2023-05-13 11:09:23,393 DEBUG plugins.jdbc-proxy :: Registering JDBC proxy driver for org.relique.jdbc.csv.CsvDriver...
# 2023-05-13 11:09:23,396 INFO metabase.util :: Load lazy loading driver :csv took 13.5 ms
# 2023-05-13 11:09:23,405 INFO metabase.task :: Initializing task CheckForNewVersions 📆
# 2023-05-13 11:09:23,420 INFO metabase.task :: Initializing task PersistPrune 📆
# 2023-05-13 11:09:23,423 INFO metabase.task :: Initializing task SendAnonymousUsageStats 📆
# 2023-05-13 11:09:23,431 INFO metabase.task :: Initializing task RefreshSlackChannelsAndUsers 📆
# 2023-05-13 11:09:23,442 INFO metabase.task :: Initializing task SendPulses 📆
# 2023-05-13 11:09:23,448 INFO metabase.task :: Initializing task SendFollowUpEmails 📆
# 2023-05-13 11:09:23,454 INFO metabase.task :: Initializing task TaskHistoryCleanup 📆
# 2023-05-13 11:09:23,462 INFO metabase.task :: Initializing task TruncateAuditLog 📆
# 2023-05-13 11:09:23,472 INFO jdbcjobstore.JobStoreTX :: ClusterManager: detected 1 failed or restarted instances.
# 2023-05-13 11:09:23,472 INFO jdbcjobstore.JobStoreTX :: ClusterManager: Scanning for instance "abdulsaboor938-meta-fqivgh561gb1683975774383"'s failed in-progress jobs.
# 2023-05-13 11:09:23,474 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683976163252 started.
# 2023-05-13 11:09:23,475 INFO metabase.task :: Task scheduler started
# 2023-05-13 11:09:23,475 INFO metabase.core :: Metabase Initialization COMPLETE
# 2023-05-13 11:09:23,493 INFO task.refresh-slack-channel-user-cache :: Slack is not configured, not refreshing slack user/channel cache.
# 2023-05-13 11:09:37,279 INFO i18n.impl :: Reading available locales from locales.clj...
# 2023-05-13 11:09:37,338 INFO util.fonts :: Reading available fonts from /frontend_client/app/fonts
# 2023-05-13 11:09:38,386 DEBUG middleware.log :: GET /api/session/properties 200 45.5 ms (4 DB calls) App DB connections: 1/4 Jetty threads: 7/50 (1 idle, 0 queued) (44 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:38,418 DEBUG middleware.log :: GET /api/user/current 200 79.6 ms (9 DB calls) App DB connections: 0/4 Jetty threads: 6/50 (2 idle, 0 queued) (44 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:38,813 DEBUG middleware.log :: GET /api/bookmark 200 17.7 ms (1 DB calls) App DB connections: 0/7 Jetty threads: 10/50 (1 idle, 0 queued) (46 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:38,816 DEBUG middleware.log :: GET /api/database 200 22.4 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 9/50 (2 idle, 0 queued) (46 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:38,818 DEBUG middleware.log :: GET /api/collection/tree 200 22.0 ms (5 DB calls) App DB connections: 0/7 Jetty threads: 9/50 (2 idle, 0 queued) (46 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:38,829 DEBUG middleware.log :: GET /api/collection/root 200 34.8 ms (2 DB calls) App DB connections: 0/7 Jetty threads: 7/50 (2 idle, 0 queued) (48 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:38,829 DEBUG middleware.log :: GET /api/search 200 33.3 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 7/50 (2 idle, 0 queued) (48 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:39,142 DEBUG middleware.log :: GET /api/timeline 200 10.5 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (48 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:39,192 DEBUG middleware.log :: GET /api/database/3/schemas 200 25.2 ms (4 DB calls) App DB connections: 1/7 Jetty threads: 7/50 (3 idle, 0 queued) (48 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:39,282 DEBUG middleware.log :: GET /api/table/5/query_metadata 200 114.7 ms (9 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (48 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:39,924 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:09:40,559 DEBUG middleware.log :: POST /api/dataset 202 [ASYNC: completed] 871.8 ms (24 DB calls) App DB connections: 0/7 Jetty threads: 5/50 (3 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 0/0 (0 threads blocked)
# 2023-05-13 11:09:49,435 DEBUG middleware.log :: GET /api/session/properties 200 14.5 ms (3 DB calls) App DB connections: 1/7 Jetty threads: 7/50 (3 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:49,442 DEBUG middleware.log :: GET /api/setting 200 21.6 ms (2 DB calls) App DB connections: 0/7 Jetty threads: 7/50 (3 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:49,912 DEBUG middleware.log :: GET /api/setup/admin_checklist 200 32.5 ms (13 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:52,893 DEBUG middleware.log :: GET /api/database 200 7.0 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:53,244 DEBUG middleware.log :: GET /api/database/3 200 8.3 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 7/50 (3 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:53,254 DEBUG middleware.log :: GET /api/database 200 16.1 ms (7 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:53,582 DEBUG middleware.log :: GET /api/database/3/metadata 200 19.9 ms (7 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:56,792 DEBUG middleware.log :: GET /api/table/5 200 15.2 ms (5 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:09:57,194 DEBUG middleware.log :: GET /api/database/3/idfields 200 9.1 ms (5 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:10:01,973 DEBUG middleware.log :: PUT /api/field/43 200 18.9 ms (9 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:10:02,445 DEBUG middleware.log :: GET /api/field/43/values 200 8.7 ms (4 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:10:03,793 DEBUG middleware.log :: GET /api/field/43/values 200 7.3 ms (3 DB calls) App DB connections: 1/7 Jetty threads: 8/50 (3 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:10:03,805 DEBUG middleware.log :: GET /api/database/3/metadata 200 20.6 ms (7 DB calls) App DB connections: 1/7 Jetty threads: 7/50 (3 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:10:03,813 DEBUG middleware.log :: GET /api/table/5/query_metadata 200 29.2 ms (9 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (55 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:10:08,885 DEBUG middleware.log :: PUT /api/field/43 200 18.3 ms (9 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:10:08,924 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:10:08,993 WARN sync.util :: Error refingerprinting field Field 43 'date'
# clojure.lang.ExceptionInfo: Error executing query: Syntax error: Encountered " "AS" "AS "" at line 2, column 90.
# Was expecting:
#     ")" ...
#      {:driver :csv, :sql ["-- Metabase" "SELECT" "  \"source\".\"substring1405\" AS \"substring1405\"" "FROM" "  (" "    SELECT" "      CAST(\"PUBLIC\".\"final_data\".\"date\" AS timestamp) AS \"date\"," "      substring(" "        CAST(\"PUBLIC\".\"final_data\".\"date\" AS timestamp)," "        1," "        1234" "      ) AS \"substring1405\"" "    FROM" "      \"PUBLIC\".\"final_data\"" "  ) \"source\"" "LIMIT" "  10000"], :params nil, :type :invalid-query}
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query$fn__71783.invoke(execute.clj:505)
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query.invokeStatic(execute.clj:502)
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query.invoke(execute.clj:489)
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query.invokeStatic(execute.clj:497)
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query.invoke(execute.clj:489)
# 	at metabase.driver.sql_jdbc$fn__105074.invokeStatic(sql_jdbc.clj:63)
# 	at metabase.driver.sql_jdbc$fn__105074.invoke(sql_jdbc.clj:61)
# 	at clojure.lang.MultiFn.invoke(MultiFn.java:244)
# 	at metabase.query_processor.context$executef.invokeStatic(context.clj:60)
# 	at metabase.query_processor.context$executef.invoke(context.clj:49)
# 	at metabase.query_processor.context.default$default_runf.invokeStatic(default.clj:68)
# 	at metabase.query_processor.context.default$default_runf.invoke(default.clj:66)
# 	at metabase.query_processor.context$runf.invokeStatic(context.clj:46)
# 	at metabase.query_processor.context$runf.invoke(context.clj:40)
# 	at metabase.query_processor.reducible$identity_qp.invokeStatic(reducible.clj:15)
# 	at metabase.query_processor.reducible$identity_qp.invoke(reducible.clj:12)
# 	at metabase.query_processor.middleware.cache$maybe_return_cached_results$maybe_return_cached_results_STAR___69168.invoke(cache.clj:224)
# 	at metabase.query_processor.middleware.permissions$check_query_permissions$fn__64640.invoke(permissions.clj:126)
# 	at metabase.query_processor.middleware.mbql_to_native$mbql__GT_native$fn__68059.invoke(mbql_to_native.clj:24)
# 	at metabase.query_processor$fn__70687$combined_post_process__70692$combined_post_process_STAR___70693.invoke(query_processor.clj:243)
# 	at metabase.query_processor$fn__70687$combined_pre_process__70688$combined_pre_process_STAR___70689.invoke(query_processor.clj:240)
# 	at metabase.query_processor.middleware.resolve_database_and_driver$resolve_database_and_driver$fn__69079$fn__69084.invoke(resolve_database_and_driver.clj:36)
# 	at metabase.driver$do_with_driver.invokeStatic(driver.clj:90)
# 	at metabase.driver$do_with_driver.invoke(driver.clj:86)
# 	at metabase.query_processor.middleware.resolve_database_and_driver$resolve_database_and_driver$fn__69079.invoke(resolve_database_and_driver.clj:35)
# 	at metabase.query_processor.middleware.fetch_source_query$resolve_card_id_source_tables$fn__64949.invoke(fetch_source_query.clj:310)
# 	at metabase.query_processor.middleware.store$initialize_store$fn__65127$fn__65128.invoke(store.clj:12)
# 	at metabase.query_processor.store$do_with_store.invokeStatic(store.clj:47)
# 	at metabase.query_processor.store$do_with_store.invoke(store.clj:41)
# 	at metabase.query_processor.middleware.store$initialize_store$fn__65127.invoke(store.clj:11)
# 	at metabase.query_processor.middleware.normalize_query$normalize$fn__69368.invoke(normalize_query.clj:25)
# 	at metabase.query_processor.reducible$async_qp$qp_STAR___59455$thunk__59457.invoke(reducible.clj:103)
# 	at metabase.query_processor.reducible$async_qp$qp_STAR___59455.invoke(reducible.clj:109)
# 	at metabase.query_processor.reducible$async_qp$qp_STAR___59455.invoke(reducible.clj:94)
# 	at clojure.lang.AFn.applyToHelper(AFn.java:156)
# 	at clojure.lang.AFn.applyTo(AFn.java:144)
# 	at clojure.core$apply.invokeStatic(core.clj:667)
# 	at clojure.core$apply.invoke(core.clj:662)
# 	at metabase.query_processor.reducible$sync_qp$qp_STAR___59467.doInvoke(reducible.clj:129)
# 	at clojure.lang.RestFn.applyTo(RestFn.java:137)
# 	at clojure.core$apply.invokeStatic(core.clj:669)
# 	at clojure.core$apply.invoke(core.clj:662)
# 	at metabase.query_processor$process_query.invokeStatic(query_processor.clj:278)
# 	at metabase.query_processor$process_query.doInvoke(query_processor.clj:272)
# 	at clojure.lang.RestFn.invoke(RestFn.java:423)
# 	at clojure.lang.Var.invoke(Var.java:388)
# 	at metabase.db.metadata_queries$fn__77195$table_rows_sample__77204$fn__77207.invoke(metadata_queries.clj:145)
# 	at metabase.db.metadata_queries$fn__77195$table_rows_sample__77204.invoke(metadata_queries.clj:132)
# 	at metabase.db.metadata_queries$fn__77226.invokeStatic(metadata_queries.clj:149)
# 	at metabase.db.metadata_queries$fn__77226.invoke(metadata_queries.clj:147)
# 	at clojure.lang.MultiFn.invoke(MultiFn.java:252)
# 	at metabase.sync.analyze.fingerprint$fn__85032$fingerprint_table_BANG___85037$fn__85038.invoke(fingerprint.clj:76)
# 	at metabase.sync.analyze.fingerprint$fn__85032$fingerprint_table_BANG___85037.invoke(fingerprint.clj:54)
# 	at metabase.sync.analyze.fingerprint$fn__85344$refingerprint_field__85349$fn__85350.invoke(fingerprint.clj:253)
# 	at metabase.sync.analyze.fingerprint$fn__85344$refingerprint_field__85349.invoke(fingerprint.clj:249)
# 	at metabase.sync$fn__85880$refingerprint_field_BANG___85885$fn__85886$fn__85887.invoke(sync.clj:76)
# 	at metabase.sync.util$do_with_error_handling.invokeStatic(util.clj:161)
# 	at metabase.sync.util$do_with_error_handling.invoke(util.clj:154)
# 	at metabase.sync$fn__85880$refingerprint_field_BANG___85885$fn__85886.invoke(sync.clj:74)
# 	at metabase.sync$fn__85880$refingerprint_field_BANG___85885.invoke(sync.clj:67)
# 	at metabase.api.field$fn__86268$fn__86280.invoke(field.clj:156)
# 	at metabase.sync.concurrent$submit_task$fn__86171.invoke(concurrent.clj:23)
# 	at clojure.lang.AFn.applyToHelper(AFn.java:152)
# 	at clojure.lang.AFn.applyTo(AFn.java:144)
# 	at clojure.core$apply.invokeStatic(core.clj:667)
# 	at clojure.core$with_bindings_STAR_.invokeStatic(core.clj:1990)
# 	at clojure.core$with_bindings_STAR_.doInvoke(core.clj:1990)
# 	at clojure.lang.RestFn.invoke(RestFn.java:425)
# 	at clojure.lang.AFn.applyToHelper(AFn.java:156)
# 	at clojure.lang.RestFn.applyTo(RestFn.java:132)
# 	at clojure.core$apply.invokeStatic(core.clj:671)
# 	at clojure.core$bound_fn_STAR_$fn__5818.doInvoke(core.clj:2020)
# 	at clojure.lang.RestFn.invoke(RestFn.java:397)
# 	at clojure.lang.AFn.call(AFn.java:18)
# 	at java.base/java.util.concurrent.FutureTask.run(FutureTask.java:264)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: java.sql.SQLException: Syntax error: Encountered " "AS" "AS "" at line 2, column 90.
# Was expecting:
#     ")" ...
#
# 	at org.relique.jdbc.csv.CsvStatement.execute(CsvStatement.java:626)
# 	at com.mchange.v2.c3p0.impl.NewProxyStatement.execute(NewProxyStatement.java:75)
# 	at metabase.driver.sql_jdbc.execute$fn__71708.invokeStatic(execute.clj:384)
# 	at metabase.driver.sql_jdbc.execute$fn__71708.invoke(execute.clj:382)
# 	at clojure.lang.MultiFn.invoke(MultiFn.java:239)
# 	at metabase.driver.sql_jdbc.execute$execute_statement_or_prepared_statement_BANG_.invokeStatic(execute.clj:392)
# 	at metabase.driver.sql_jdbc.execute$execute_statement_or_prepared_statement_BANG_.invoke(execute.clj:389)
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query$fn__71783.invoke(execute.clj:503)
# 	... 77 more
# 2023-05-13 11:10:09,231 DEBUG middleware.log :: GET /api/field/43/values 200 7.0 ms (4 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:10:11,232 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:10:11,250 ERROR models.field-values :: Error fetching field values
# clojure.lang.ExceptionInfo: Error executing query: Syntax error: Encountered " "AS" "AS "" at line 2, column 43.
# Was expecting:
#     ")" ...
#      {:driver :csv, :sql ["-- Metabase" "SELECT" "  substring(" "    CAST(\"PUBLIC\".\"final_data\".\"date\" AS timestamp)," "    1," "    10" "  ) AS \"date\"" "FROM" "  \"PUBLIC\".\"final_data\"" "GROUP BY" "  substring(" "    CAST(\"PUBLIC\".\"final_data\".\"date\" AS timestamp)," "    1," "    10" "  )" "ORDER BY" "  substring(" "    CAST(\"PUBLIC\".\"final_data\".\"date\" AS timestamp)," "    1," "    10" "  ) ASC" "LIMIT" "  1000"], :params nil, :type :invalid-query}
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query$fn__71783.invoke(execute.clj:505)
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query.invokeStatic(execute.clj:502)
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query.invoke(execute.clj:489)
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query.invokeStatic(execute.clj:497)
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query.invoke(execute.clj:489)
# 	at metabase.driver.sql_jdbc$fn__105074.invokeStatic(sql_jdbc.clj:63)
# 	at metabase.driver.sql_jdbc$fn__105074.invoke(sql_jdbc.clj:61)
# 	at clojure.lang.MultiFn.invoke(MultiFn.java:244)
# 	at metabase.query_processor.context$executef.invokeStatic(context.clj:60)
# 	at metabase.query_processor.context$executef.invoke(context.clj:49)
# 	at metabase.query_processor.context.default$default_runf.invokeStatic(default.clj:68)
# 	at metabase.query_processor.context.default$default_runf.invoke(default.clj:66)
# 	at metabase.query_processor.context$runf.invokeStatic(context.clj:46)
# 	at metabase.query_processor.context$runf.invoke(context.clj:40)
# 	at metabase.query_processor.reducible$identity_qp.invokeStatic(reducible.clj:15)
# 	at metabase.query_processor.reducible$identity_qp.invoke(reducible.clj:12)
# 	at metabase.query_processor.middleware.cache$maybe_return_cached_results$maybe_return_cached_results_STAR___69168.invoke(cache.clj:224)
# 	at metabase.query_processor.middleware.permissions$check_query_permissions$fn__64640.invoke(permissions.clj:126)
# 	at metabase.query_processor.middleware.mbql_to_native$mbql__GT_native$fn__68059.invoke(mbql_to_native.clj:24)
# 	at metabase.query_processor$fn__70687$combined_post_process__70692$combined_post_process_STAR___70693.invoke(query_processor.clj:243)
# 	at metabase.query_processor$fn__70687$combined_pre_process__70688$combined_pre_process_STAR___70689.invoke(query_processor.clj:240)
# 	at metabase.query_processor.middleware.resolve_database_and_driver$resolve_database_and_driver$fn__69079$fn__69084.invoke(resolve_database_and_driver.clj:36)
# 	at metabase.driver$do_with_driver.invokeStatic(driver.clj:90)
# 	at metabase.driver$do_with_driver.invoke(driver.clj:86)
# 	at metabase.query_processor.middleware.resolve_database_and_driver$resolve_database_and_driver$fn__69079.invoke(resolve_database_and_driver.clj:35)
# 	at metabase.query_processor.middleware.fetch_source_query$resolve_card_id_source_tables$fn__64949.invoke(fetch_source_query.clj:310)
# 	at metabase.query_processor.middleware.store$initialize_store$fn__65127$fn__65128.invoke(store.clj:12)
# 	at metabase.query_processor.store$do_with_store.invokeStatic(store.clj:47)
# 	at metabase.query_processor.store$do_with_store.invoke(store.clj:41)
# 	at metabase.query_processor.middleware.store$initialize_store$fn__65127.invoke(store.clj:11)
# 	at metabase.query_processor.middleware.normalize_query$normalize$fn__69368.invoke(normalize_query.clj:25)
# 	at metabase.query_processor.reducible$async_qp$qp_STAR___59455$thunk__59457.invoke(reducible.clj:103)
# 	at metabase.query_processor.reducible$async_qp$qp_STAR___59455.invoke(reducible.clj:109)
# 	at metabase.query_processor.reducible$async_qp$qp_STAR___59455.invoke(reducible.clj:94)
# 	at metabase.query_processor.reducible$async_qp$qp_STAR___59455.invoke(reducible.clj:91)
# 	at clojure.lang.AFn.applyToHelper(AFn.java:154)
# 	at clojure.lang.AFn.applyTo(AFn.java:144)
# 	at clojure.core$apply.invokeStatic(core.clj:667)
# 	at clojure.core$apply.invoke(core.clj:662)
# 	at metabase.query_processor.reducible$sync_qp$qp_STAR___59467.doInvoke(reducible.clj:129)
# 	at clojure.lang.RestFn.applyTo(RestFn.java:137)
# 	at clojure.core$apply.invokeStatic(core.clj:669)
# 	at clojure.core$apply.invoke(core.clj:662)
# 	at metabase.query_processor$process_query.invokeStatic(query_processor.clj:278)
# 	at metabase.query_processor$process_query.doInvoke(query_processor.clj:272)
# 	at clojure.lang.RestFn.invoke(RestFn.java:410)
# 	at metabase.db.metadata_queries$qp_query$fn__77081.invoke(metadata_queries.clj:23)
# 	at metabase.db.metadata_queries$qp_query.invokeStatic(metadata_queries.clj:22)
# 	at metabase.db.metadata_queries$qp_query.invoke(metadata_queries.clj:20)
# 	at metabase.db.metadata_queries$field_query.invokeStatic(metadata_queries.clj:33)
# 	at metabase.db.metadata_queries$field_query.invoke(metadata_queries.clj:31)
# 	at metabase.db.metadata_queries$fn__77098$field_distinct_values__77107$fn__77110.invoke(metadata_queries.clj:65)
# 	at metabase.db.metadata_queries$fn__77098$field_distinct_values__77107.invoke(metadata_queries.clj:58)
# 	at metabase.db.metadata_queries$fn__77098$field_distinct_values__77107$fn__77108.invoke(metadata_queries.clj:62)
# 	at metabase.db.metadata_queries$fn__77098$field_distinct_values__77107.invoke(metadata_queries.clj:58)
# 	at clojure.lang.Var.invoke(Var.java:384)
# 	at metabase.models.field_values$distinct_values.invokeStatic(field_values.clj:306)
# 	at metabase.models.field_values$distinct_values.invoke(field_values.clj:291)
# 	at metabase.models.field_values$create_or_update_full_field_values_BANG_.invokeStatic(field_values.clj:333)
# 	at metabase.models.field_values$create_or_update_full_field_values_BANG_.doInvoke(field_values.clj:325)
# 	at clojure.lang.RestFn.invoke(RestFn.java:410)
# 	at metabase.api.field$fn__86326$fn__86327.invoke(field.clj:319)
# 	at metabase.api.field$fn__86326.invokeStatic(field.clj:318)
# 	at metabase.api.field$fn__86326.invoke(field.clj:310)
# 	at compojure.core$wrap_response$fn__42375.invoke(core.clj:160)
# 	at compojure.core$wrap_route_middleware$fn__42359.invoke(core.clj:132)
# 	at compojure.core$wrap_route_info$fn__42364.invoke(core.clj:139)
# 	at compojure.core$wrap_route_matches$fn__42368.invoke(core.clj:151)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$wrap_route_matches$fn__42368.invoke(core.clj:152)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$wrap_route_matches$fn__42368.invoke(core.clj:153)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387.invoke(core.clj:200)
# 	at metabase.server.middleware.auth$enforce_authentication$fn__86624.invoke(auth.clj:17)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387.invoke(core.clj:200)
# 	at compojure.core$make_context$handler__42415.invoke(core.clj:290)
# 	at compojure.core$make_context$fn__42419.invoke(core.clj:300)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$make_context$fn__42419.invoke(core.clj:301)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$make_context$fn__42419.invoke(core.clj:301)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$make_context$fn__42419.invoke(core.clj:301)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$make_context$fn__42419.invoke(core.clj:301)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$make_context$fn__42419.invoke(core.clj:301)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$make_context$fn__42419.invoke(core.clj:301)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$make_context$fn__42419.invoke(core.clj:301)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$make_context$fn__42419.invoke(core.clj:301)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$make_context$fn__42419.invoke(core.clj:301)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$make_context$fn__42419.invoke(core.clj:301)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$make_context$fn__42419.invoke(core.clj:301)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$make_context$fn__42419.invoke(core.clj:301)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at metabase.api.routes$fn__98449$fn__98452.invoke(routes.clj:64)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387.invoke(core.clj:200)
# 	at clojure.lang.AFn.applyToHelper(AFn.java:160)
# 	at clojure.lang.AFn.applyTo(AFn.java:144)
# 	at clojure.core$apply.invokeStatic(core.clj:667)
# 	at clojure.core$apply.invoke(core.clj:662)
# 	at metabase.server.routes$fn__98610$fn__98611.doInvoke(routes.clj:70)
# 	at clojure.lang.RestFn.invoke(RestFn.java:436)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387.invoke(core.clj:200)
# 	at compojure.core$make_context$handler__42415.invoke(core.clj:290)
# 	at compojure.core$make_context$fn__42419.invoke(core.clj:300)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$wrap_route_matches$fn__42368.invoke(core.clj:153)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$wrap_route_matches$fn__42368.invoke(core.clj:153)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at compojure.core$wrap_route_matches$fn__42368.invoke(core.clj:153)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387$f__42388$respond_SINGLEQUOTE___42389.invoke(core.clj:197)
# 	at metabase.server.routes$fn__98595$fn__98597.invoke(routes.clj:47)
# 	at compojure.core$routes$fn__42387$f__42388.invoke(core.clj:198)
# 	at compojure.core$routes$fn__42387.invoke(core.clj:200)
# 	at metabase.server.middleware.exceptions$catch_uncaught_exceptions$fn__95133.invoke(exceptions.clj:103)
# 	at metabase.server.middleware.exceptions$catch_api_exceptions$fn__95130.invoke(exceptions.clj:91)
# 	at metabase.server.middleware.log$log_api_call$fn__100334$fn__100335$fn__100336.invoke(log.clj:216)
# 	at metabase.driver.sql_jdbc.execute.diagnostic$do_with_diagnostic_info.invokeStatic(diagnostic.clj:18)
# 	at metabase.driver.sql_jdbc.execute.diagnostic$do_with_diagnostic_info.invoke(diagnostic.clj:12)
# 	at metabase.server.middleware.log$log_api_call$fn__100334$fn__100335.invoke(log.clj:208)
# 	at toucan2.execute$do_with_call_counts.invokeStatic(execute.clj:112)
# 	at toucan2.execute$do_with_call_counts.invoke(execute.clj:103)
# 	at metabase.server.middleware.log$log_api_call$fn__100334.invoke(log.clj:207)
# 	at metabase.server.middleware.browser_cookie$ensure_browser_id_cookie$fn__103755.invoke(browser_cookie.clj:42)
# 	at metabase.server.middleware.security$add_security_headers$fn__79453.invoke(security.clj:153)
# 	at metabase.server.middleware.json$wrap_json_body$fn__102499.invoke(json.clj:67)
# 	at metabase.server.middleware.offset_paging$handle_paging$fn__79477.invoke(offset_paging.clj:45)
# 	at metabase.server.middleware.json$wrap_streamed_json_response$fn__102517.invoke(json.clj:103)
# 	at ring.middleware.keyword_params$wrap_keyword_params$fn__104022.invoke(keyword_params.clj:55)
# 	at ring.middleware.params$wrap_params$fn__104041.invoke(params.clj:77)
# 	at metabase.server.middleware.misc$maybe_set_site_url$fn__50479.invoke(misc.clj:61)
# 	at metabase.server.middleware.session$reset_session_timeout$fn__63769.invoke(session.clj:430)
# 	at metabase.server.middleware.session$bind_current_user$fn__63739$fn__63740.invoke(session.clj:336)
# 	at metabase.server.middleware.session$do_with_current_user.invokeStatic(session.clj:315)
# 	at metabase.server.middleware.session$do_with_current_user.invoke(session.clj:304)
# 	at metabase.server.middleware.session$bind_current_user$fn__63739.invoke(session.clj:335)
# 	at metabase.server.middleware.session$wrap_current_user_info$fn__63721.invoke(session.clj:285)
# 	at metabase.server.middleware.session$wrap_session_id$fn__63704.invoke(session.clj:217)
# 	at metabase.server.middleware.auth$wrap_api_key$fn__86632.invoke(auth.clj:30)
# 	at ring.middleware.cookies$wrap_cookies$fn__103942.invoke(cookies.clj:216)
# 	at metabase.server.middleware.misc$add_content_type$fn__50461.invoke(misc.clj:29)
# 	at metabase.server.middleware.misc$disable_streaming_buffering$fn__50487.invoke(misc.clj:78)
# 	at ring.middleware.gzip$wrap_gzip$fn__103984.invoke(gzip.clj:86)
# 	at metabase.server.middleware.misc$bind_request$fn__50490.invoke(misc.clj:95)
# 	at metabase.server.middleware.ssl$redirect_to_https_middleware$fn__103771.invoke(ssl.clj:41)
# 	at metabase.server$async_proxy_handler$fn__99100.invoke(server.clj:77)
# 	at metabase.server.proxy$org.eclipse.jetty.server.handler.AbstractHandler$ff19274a.handle(Unknown Source)
# 	at org.eclipse.jetty.server.handler.StatisticsHandler.handle(StatisticsHandler.java:173)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:122)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:563)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$0(HttpChannel.java:505)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:762)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:497)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:282)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:314)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:100)
# 	at org.eclipse.jetty.io.SelectableChannelEndPoint$1.run(SelectableChannelEndPoint.java:53)
# 	at org.eclipse.jetty.util.thread.strategy.AdaptiveExecutionStrategy.runTask(AdaptiveExecutionStrategy.java:416)
# 	at org.eclipse.jetty.util.thread.strategy.AdaptiveExecutionStrategy.consumeTask(AdaptiveExecutionStrategy.java:385)
# 	at org.eclipse.jetty.util.thread.strategy.AdaptiveExecutionStrategy.tryProduce(AdaptiveExecutionStrategy.java:272)
# 	at org.eclipse.jetty.util.thread.strategy.AdaptiveExecutionStrategy.lambda$new$0(AdaptiveExecutionStrategy.java:140)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:411)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:936)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1080)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: java.sql.SQLException: Syntax error: Encountered " "AS" "AS "" at line 2, column 43.
# Was expecting:
#     ")" ...
#
# 	at org.relique.jdbc.csv.CsvStatement.execute(CsvStatement.java:626)
# 	at com.mchange.v2.c3p0.impl.NewProxyStatement.execute(NewProxyStatement.java:75)
# 	at metabase.driver.sql_jdbc.execute$fn__71708.invokeStatic(execute.clj:384)
# 	at metabase.driver.sql_jdbc.execute$fn__71708.invoke(execute.clj:382)
# 	at clojure.lang.MultiFn.invoke(MultiFn.java:239)
# 	at metabase.driver.sql_jdbc.execute$execute_statement_or_prepared_statement_BANG_.invokeStatic(execute.clj:392)
# 	at metabase.driver.sql_jdbc.execute$execute_statement_or_prepared_statement_BANG_.invoke(execute.clj:389)
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query$fn__71783.invoke(execute.clj:503)
# 	... 196 more
# 2023-05-13 11:10:11,256 DEBUG middleware.log :: POST /api/field/43/rescan_values 200 56.3 ms (10 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 0/2 (0 threads blocked)
# 2023-05-13 11:10:13,692 DEBUG middleware.log :: GET /api/activity/recent_views 200 21.1 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 8/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:10:13,699 DEBUG middleware.log :: GET /api/activity/popular_items 200 28.6 ms (6 DB calls) App DB connections: 0/7 Jetty threads: 7/50 (3 idle, 0 queued) (56 total active threads) Queries in flight: 0 (0 queued)
# ...
#   "query_processor.middleware.mbql_to_native$mbql__GT_native$fn__68059.invoke(mbql_to_native.clj:24)"
#   "query_processor$fn__70687$combined_post_process__70692$combined_post_process_STAR___70693.invoke(query_processor.clj:243)"
#   "query_processor$fn__70687$combined_pre_process__70688$combined_pre_process_STAR___70689.invoke(query_processor.clj:240)"
#   "query_processor.middleware.resolve_database_and_driver$resolve_database_and_driver$fn__69079$fn__69084.invoke(resolve_database_and_driver.clj:36)"
#   "driver$do_with_driver.invokeStatic(driver.clj:90)"
#   "driver$do_with_driver.invoke(driver.clj:86)"
#   "query_processor.middleware.resolve_database_and_driver$resolve_database_and_driver$fn__69079.invoke(resolve_database_and_driver.clj:35)"
#   "query_processor.middleware.fetch_source_query$resolve_card_id_source_tables$fn__64949.invoke(fetch_source_query.clj:310)"
#   "query_processor.middleware.store$initialize_store$fn__65127$fn__65128.invoke(store.clj:12)"
#   "query_processor.store$do_with_store.invokeStatic(store.clj:47)"
#   "query_processor.store$do_with_store.invoke(store.clj:41)"
#   "query_processor.middleware.store$initialize_store$fn__65127.invoke(store.clj:11)"
#   "query_processor.middleware.normalize_query$normalize$fn__69368.invoke(normalize_query.clj:25)"
#   "query_processor.middleware.constraints$add_default_userland_constraints$fn__66305.invoke(constraints.clj:54)"
#   "query_processor.middleware.process_userland_query$process_userland_query$fn__69304.invoke(process_userland_query.clj:150)"
#   "query_processor.middleware.catch_exceptions$catch_exceptions$fn__69681.invoke(catch_exceptions.clj:171)"
#   "query_processor.reducible$async_qp$qp_STAR___59455$thunk__59457.invoke(reducible.clj:103)"
#   "query_processor.reducible$async_qp$qp_STAR___59455.invoke(reducible.clj:109)"
#   "query_processor.reducible$async_qp$qp_STAR___59455.invoke(reducible.clj:94)"
#   "query_processor.reducible$sync_qp$qp_STAR___59467.doInvoke(reducible.clj:129)"
#   "query_processor$process_userland_query.invokeStatic(query_processor.clj:362)"
#   "query_processor$process_userland_query.doInvoke(query_processor.clj:358)"
#   "query_processor$fn__70735$process_query_and_save_execution_BANG___70744$fn__70747.invoke(query_processor.clj:373)"
#   "query_processor$fn__70735$process_query_and_save_execution_BANG___70744.invoke(query_processor.clj:366)"
#   "query_processor$fn__70780$process_query_and_save_with_max_results_constraints_BANG___70789$fn__70792.invoke(query_processor.clj:385)"
#   "query_processor$fn__70780$process_query_and_save_with_max_results_constraints_BANG___70789.invoke(query_processor.clj:378)"
#   "api.dataset$run_query_async$fn__86532.invoke(dataset.clj:73)"
#   "query_processor.streaming$streaming_response_STAR_$fn__54305$fn__54306.invoke(streaming.clj:166)"
#   "query_processor.streaming$streaming_response_STAR_$fn__54305.invoke(streaming.clj:165)"
#   "async.streaming_response$do_f_STAR_.invokeStatic(streaming_response.clj:69)"
#   "async.streaming_response$do_f_STAR_.invoke(streaming_response.clj:67)"
#   "async.streaming_response$do_f_async$task__36922.invoke(streaming_response.clj:88)"],
#  :card_id nil,
#  :context :ad-hoc,
#  :error "Syntax error: Encountered \" \"AS\" \"AS \"\" at line 2, column 33.\nWas expecting:\n    \")\" ...\n    ",
#  :row_count 0,
#  :running_time 0,
#  :preprocessed
#  {:database 3,
#   :query
#   {:source-table 5,
#    :fields
#    [[:field 43 {:temporal-unit :default}]
#     [:field 41 nil]
#     [:field 47 nil]
#     [:field 42 nil]
#     [:field 44 nil]
#     [:field 39 nil]
#     [:field 45 nil]
#     [:field 38 nil]
#     [:field 37 nil]
#     [:field 48 nil]
#     [:field 46 nil]
#     [:field 40 nil]],
#    :limit 1048575,
#    :metabase.query-processor.middleware.limit/original-limit nil},
#   :type :query,
#   :middleware {:js-int-to-string? true, :add-default-userland-constraints? true},
#   :info {:executed-by 1, :context :ad-hoc}},
#  :data {:rows [], :cols []}}
#
# 2023-05-13 11:11:05,381 DEBUG middleware.log :: POST /api/dataset 202 [ASYNC: completed] 217.3 ms (22 DB calls) App DB connections: 0/7 Jetty threads: 5/50 (2 idle, 0 queued) (64 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 0/2 (0 threads blocked)
# 2023-05-13 11:11:15,635 DEBUG middleware.log :: PUT /api/field/43 200 10.9 ms (9 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (2 idle, 0 queued) (64 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:11:15,649 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:11:15,672 WARN sync.util :: Error refingerprinting field Field 43 'date'
# clojure.lang.ExceptionInfo: Error executing query: Syntax error: derived tables not supported {:driver :csv, :sql ["-- Metabase" "SELECT" "  \"source\".\"substring1510\" AS \"substring1510\"" "FROM" "  (" "    SELECT" "      \"PUBLIC\".\"final_data\".\"date\" AS \"date\"," "      substring(\"PUBLIC\".\"final_data\".\"date\", 1, 1234) AS \"substring1510\"" "    FROM" "      \"PUBLIC\".\"final_data\"" "  ) \"source\"" "LIMIT" "  10000"], :params nil, :type :invalid-query}
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query$fn__71783.invoke(execute.clj:505)
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query.invokeStatic(execute.clj:502)
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query.invoke(execute.clj:489)
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query.invokeStatic(execute.clj:497)
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query.invoke(execute.clj:489)
# 	at metabase.driver.sql_jdbc$fn__105074.invokeStatic(sql_jdbc.clj:63)
# 	at metabase.driver.sql_jdbc$fn__105074.invoke(sql_jdbc.clj:61)
# 	at clojure.lang.MultiFn.invoke(MultiFn.java:244)
# 	at metabase.query_processor.context$executef.invokeStatic(context.clj:60)
# 	at metabase.query_processor.context$executef.invoke(context.clj:49)
# 	at metabase.query_processor.context.default$default_runf.invokeStatic(default.clj:68)
# 	at metabase.query_processor.context.default$default_runf.invoke(default.clj:66)
# 	at metabase.query_processor.context$runf.invokeStatic(context.clj:46)
# 	at metabase.query_processor.context$runf.invoke(context.clj:40)
# 	at metabase.query_processor.reducible$identity_qp.invokeStatic(reducible.clj:15)
# 	at metabase.query_processor.reducible$identity_qp.invoke(reducible.clj:12)
# 	at metabase.query_processor.middleware.cache$maybe_return_cached_results$maybe_return_cached_results_STAR___69168.invoke(cache.clj:224)
# 	at metabase.query_processor.middleware.permissions$check_query_permissions$fn__64640.invoke(permissions.clj:126)
# 	at metabase.query_processor.middleware.mbql_to_native$mbql__GT_native$fn__68059.invoke(mbql_to_native.clj:24)
# 	at metabase.query_processor$fn__70687$combined_post_process__70692$combined_post_process_STAR___70693.invoke(query_processor.clj:243)
# 	at metabase.query_processor$fn__70687$combined_pre_process__70688$combined_pre_process_STAR___70689.invoke(query_processor.clj:240)
# 	at metabase.query_processor.middleware.resolve_database_and_driver$resolve_database_and_driver$fn__69079$fn__69084.invoke(resolve_database_and_driver.clj:36)
# 	at metabase.driver$do_with_driver.invokeStatic(driver.clj:90)
# 	at metabase.driver$do_with_driver.invoke(driver.clj:86)
# 	at metabase.query_processor.middleware.resolve_database_and_driver$resolve_database_and_driver$fn__69079.invoke(resolve_database_and_driver.clj:35)
# 	at metabase.query_processor.middleware.fetch_source_query$resolve_card_id_source_tables$fn__64949.invoke(fetch_source_query.clj:310)
# 	at metabase.query_processor.middleware.store$initialize_store$fn__65127$fn__65128.invoke(store.clj:12)
# 	at metabase.query_processor.store$do_with_store.invokeStatic(store.clj:47)
# 	at metabase.query_processor.store$do_with_store.invoke(store.clj:41)
# 	at metabase.query_processor.middleware.store$initialize_store$fn__65127.invoke(store.clj:11)
# 	at metabase.query_processor.middleware.normalize_query$normalize$fn__69368.invoke(normalize_query.clj:25)
# 	at metabase.query_processor.reducible$async_qp$qp_STAR___59455$thunk__59457.invoke(reducible.clj:103)
# 	at metabase.query_processor.reducible$async_qp$qp_STAR___59455.invoke(reducible.clj:109)
# 	at metabase.query_processor.reducible$async_qp$qp_STAR___59455.invoke(reducible.clj:94)
# 	at clojure.lang.AFn.applyToHelper(AFn.java:156)
# 	at clojure.lang.AFn.applyTo(AFn.java:144)
# 	at clojure.core$apply.invokeStatic(core.clj:667)
# 	at clojure.core$apply.invoke(core.clj:662)
# 	at metabase.query_processor.reducible$sync_qp$qp_STAR___59467.doInvoke(reducible.clj:129)
# 	at clojure.lang.RestFn.applyTo(RestFn.java:137)
# 	at clojure.core$apply.invokeStatic(core.clj:669)
# 	at clojure.core$apply.invoke(core.clj:662)
# 	at metabase.query_processor$process_query.invokeStatic(query_processor.clj:278)
# 	at metabase.query_processor$process_query.doInvoke(query_processor.clj:272)
# 	at clojure.lang.RestFn.invoke(RestFn.java:423)
# 	at clojure.lang.Var.invoke(Var.java:388)
# 	at metabase.db.metadata_queries$fn__77195$table_rows_sample__77204$fn__77207.invoke(metadata_queries.clj:145)
# 	at metabase.db.metadata_queries$fn__77195$table_rows_sample__77204.invoke(metadata_queries.clj:132)
# 	at metabase.db.metadata_queries$fn__77226.invokeStatic(metadata_queries.clj:149)
# 	at metabase.db.metadata_queries$fn__77226.invoke(metadata_queries.clj:147)
# 	at clojure.lang.MultiFn.invoke(MultiFn.java:252)
# 	at metabase.sync.analyze.fingerprint$fn__85032$fingerprint_table_BANG___85037$fn__85038.invoke(fingerprint.clj:76)
# 	at metabase.sync.analyze.fingerprint$fn__85032$fingerprint_table_BANG___85037.invoke(fingerprint.clj:54)
# 	at metabase.sync.analyze.fingerprint$fn__85344$refingerprint_field__85349$fn__85350.invoke(fingerprint.clj:253)
# 	at metabase.sync.analyze.fingerprint$fn__85344$refingerprint_field__85349.invoke(fingerprint.clj:249)
# 	at metabase.sync$fn__85880$refingerprint_field_BANG___85885$fn__85886$fn__85887.invoke(sync.clj:76)
# 	at metabase.sync.util$do_with_error_handling.invokeStatic(util.clj:161)
# 	at metabase.sync.util$do_with_error_handling.invoke(util.clj:154)
# 	at metabase.sync$fn__85880$refingerprint_field_BANG___85885$fn__85886.invoke(sync.clj:74)
# 	at metabase.sync$fn__85880$refingerprint_field_BANG___85885.invoke(sync.clj:67)
# 	at metabase.api.field$fn__86268$fn__86280.invoke(field.clj:156)
# 	at metabase.sync.concurrent$submit_task$fn__86171.invoke(concurrent.clj:23)
# 	at clojure.lang.AFn.applyToHelper(AFn.java:152)
# 	at clojure.lang.AFn.applyTo(AFn.java:144)
# 	at clojure.core$apply.invokeStatic(core.clj:667)
# 	at clojure.core$with_bindings_STAR_.invokeStatic(core.clj:1990)
# 	at clojure.core$with_bindings_STAR_.doInvoke(core.clj:1990)
# 	at clojure.lang.RestFn.invoke(RestFn.java:425)
# 	at clojure.lang.AFn.applyToHelper(AFn.java:156)
# 	at clojure.lang.RestFn.applyTo(RestFn.java:132)
# 	at clojure.core$apply.invokeStatic(core.clj:671)
# 	at clojure.core$bound_fn_STAR_$fn__5818.doInvoke(core.clj:2020)
# 	at clojure.lang.RestFn.invoke(RestFn.java:397)
# 	at clojure.lang.AFn.call(AFn.java:18)
# 	at java.base/java.util.concurrent.FutureTask.run(FutureTask.java:264)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# Caused by: java.sql.SQLException: Syntax error: derived tables not supported
# 	at org.relique.jdbc.csv.CsvStatement.execute(CsvStatement.java:626)
# 	at com.mchange.v2.c3p0.impl.NewProxyStatement.execute(NewProxyStatement.java:75)
# 	at metabase.driver.sql_jdbc.execute$fn__71708.invokeStatic(execute.clj:384)
# 	at metabase.driver.sql_jdbc.execute$fn__71708.invoke(execute.clj:382)
# 	at clojure.lang.MultiFn.invoke(MultiFn.java:239)
# 	at metabase.driver.sql_jdbc.execute$execute_statement_or_prepared_statement_BANG_.invokeStatic(execute.clj:392)
# 	at metabase.driver.sql_jdbc.execute$execute_statement_or_prepared_statement_BANG_.invoke(execute.clj:389)
# 	at metabase.driver.sql_jdbc.execute$execute_reducible_query$fn__71783.invoke(execute.clj:503)
# 	... 77 more
# 2023-05-13 11:11:16,024 DEBUG middleware.log :: GET /api/field/43/values 200 5.5 ms (4 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (2 idle, 0 queued) (64 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:11:18,101 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:11:21,386 DEBUG middleware.log :: GET /api/user/current 200 9.8 ms (8 DB calls) App DB connections: 0/7 Jetty threads: 8/50 (2 idle, 0 queued) (64 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:11:21,389 DEBUG middleware.log :: GET /api/session/properties 200 11.1 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 7/50 (2 idle, 0 queued) (64 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:11:21,738 DEBUG middleware.log :: GET /api/collection/root 200 7.6 ms (2 DB calls) App DB connections: 2/7 Jetty threads: 11/50 (0 idle, 0 queued) (64 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:11:21,740 DEBUG middleware.log :: GET /api/database 200 5.9 ms (3 DB calls) App DB connections: 3/7 Jetty threads: 10/50 (0 idle, 0 queued) (64 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:11:21,741 DEBUG middleware.log :: GET /api/bookmark 200 3.9 ms (1 DB calls) App DB connections: 0/7 Jetty threads: 10/50 (0 idle, 0 queued) (64 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:11:21,741 DEBUG middleware.log :: GET /api/search 200 6.3 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 10/50 (0 idle, 0 queued) (64 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:11:21,744 DEBUG middleware.log :: GET /api/collection/tree 200 8.5 ms (5 DB calls) App DB connections: 1/7 Jetty threads: 9/50 (0 idle, 0 queued) (64 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:11:22,102 DEBUG middleware.log :: GET /api/timeline 200 3.2 ms (3 DB calls) App DB connections: 0/7 Jetty threads: 7/50 (1 idle, 0 queued) (64 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:11:22,116 DEBUG middleware.log :: GET /api/database/3/schemas 200 5.8 ms (4 DB calls) App DB connections: 0/7 Jetty threads: 8/50 (1 idle, 0 queued) (64 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:11:22,137 DEBUG middleware.log :: GET /api/table/5/query_metadata 200 26.3 ms (9 DB calls) App DB connections: 0/7 Jetty threads: 7/50 (1 idle, 0 queued) (64 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:11:22,587 WARN query-processor.deprecated :: Warning: Driver :csv is using Honey SQL 1. This method was deprecated in 0.46.0 and will be removed in a future release.
# 2023-05-13 11:11:23,395 DEBUG middleware.log :: POST /api/dataset 202 [ASYNC: completed] 841.7 ms (24 DB calls) App DB connections: 1/7 Jetty threads: 6/50 (1 idle, 0 queued) (66 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 1/2 (0 threads blocked)
# 2023-05-13 11:11:34,466 DEBUG middleware.log :: POST /api/field/43/rescan_values 200 16.4 s (15 DB calls) App DB connections: 0/7 Jetty threads: 6/50 (1 idle, 0 queued) (66 total active threads) Queries in flight: 0 (0 queued); csv DB 3 connections: 0/2 (0 threads blocked)
# ^C
# 2023-05-13 11:13:10,619 INFO metabase.core :: Metabase Shutting Down ...
# 2023-05-13 11:13:10,619 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683976163252 shutting down.
# 2023-05-13 11:13:10,619 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683976163252 paused.
# 2023-05-13 11:13:10,621 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683976163252 shutdown complete.
# 2023-05-13 11:13:10,621 INFO metabase.server :: Shutting Down Embedded Jetty Webserver
# 2023-05-13 11:13:10,625 INFO metabase.core :: Metabase Shutdown COMPLETE
