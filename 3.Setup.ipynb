# %%
# !pip install pandas
# !pip install numpy
import pandas as pd
import numpy as np
# Fuction
def combine_predictions(zone):

    temp = pd.read_csv(f'raw_data/{zone}.csv')

    temp['pred_temp'] = np.nan
    temp['pred_pm25'] = np.nan
    temp['pred_pm10'] = np.nan
    temp['pred_smog'] = np.nan

    temp1 = pd.read_csv(f'prediction/{zone}.csv')
    temp1.columns = ['date','zone','longitude','latitude','pred_temp','pred_pm25','pred_pm10','pred_smog']

    temp1['temperature'] = np.nan
    temp1['pm2_5']=np.nan
    temp1['pm10']=np.nan
    temp1['smog']=np.nan

    temp1=temp1[['date','zone','longitude','latitude','temperature','pm2_5','pm10','smog','pred_temp','pred_pm25','pred_pm10','pred_smog']]

    return(pd.concat([temp,temp1]))

# check if final_data.csv exists
import os.path
from os import path
if path.exists("final_data.csv"):
    print("final_data.csv exists")
else:
    # Writing back to files
    df = combine_predictions(1)
    df.to_csv('final_data.csv', index=False)

    for i in range(2,249):
        combine_predictions(i).to_csv('final_data.csv', mode='a', header=False, index=False)
        print(f"{i} done")
# Out:
# Requirement already satisfied: pandas in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: numpy in /home/gitpod/.pyenv/versions/3.11.1/lib/python3.11/site-packages (1.24.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# final_data.csv exists

# %%
# # metabase operations

# going to metabase folder
# %cd ./metabase

# check if metabase.jar is present, if not download it
import os.path
from os import path
if path.exists("metabase.jar"):
    print("File exists")
else:
    print("File does not exist, downloading...")
    # !wget http://downloads.metabase.com/v0.46.0/metabase.jar

# run metabase
# !java -jar metabase.jar
# Out:
# /workspace/meta/metabase
# File does not exist, downloading...
# --2023-05-13 10:58:38--  http://downloads.metabase.com/v0.46.0/metabase.jar
# Resolving downloads.metabase.com (downloads.metabase.com)... 52.84.162.115, 52.84.162.86, 52.84.162.97, ...
# Connecting to downloads.metabase.com (downloads.metabase.com)|52.84.162.115|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.metabase.com/v0.46.0/metabase.jar [following]
# --2023-05-13 10:58:38--  https://downloads.metabase.com/v0.46.0/metabase.jar
# Connecting to downloads.metabase.com (downloads.metabase.com)|52.84.162.115|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 291887157 (278M) [application/java-archive]
# Saving to: ‘metabase.jar’
#
# metabase.jar        100%[===================>] 278.37M  44.7MB/s    in 6.7s
#
# 2023-05-13 10:58:45 (41.8 MB/s) - ‘metabase.jar’ saved [291887157/291887157]
#
# Picked up JAVA_TOOL_OPTIONS:  -Xmx12884m
# Warning: environ value /home/gitpod/.sdkman/candidates/java/current for key :java-home has been overwritten with /home/gitpod/.sdkman/candidates/java/11.0.19.fx-zulu
# 2023-05-13 10:58:51,209 INFO metabase.util :: Maximum memory available to JVM: 12.6 GB
# 2023-05-13 10:58:52,485 WARN db.env :: WARNING: Using Metabase with an H2 application database is not recommended for production deployments. For production deployments, we highly recommend using Postgres, MySQL, or MariaDB instead. If you decide to continue to use H2, please be sure to back up the database file regularly. For more information, see https://metabase.com/docs/latest/operations-guide/migrating-from-h2.html
# 2023-05-13 10:58:52,637 INFO util.encryption :: Saved credentials encryption is DISABLED for this Metabase instance. 🔓
#  For more information, see https://metabase.com/docs/latest/operations-guide/encrypting-database-details-at-rest.html
# ..instrumented #'metabase.util.malli/with-api-error-message
# ..instrumented #'metabase.util.honey-sql-2/identifier
# ..instrumented #'metabase.util.honey-sql-2/normalize-type-info
# ..instrumented #'metabase.util.honey-sql-2/with-database-type-info
# ..instrumented #'metabase.util.honey-sql-2/cast
# ..instrumented #'metabase.util.honey-sql-2/quoted-cast
# ..instrumented #'metabase.util.honey-sql-2/maybe-cast
# ..instrumented #'metabase.models.permissions/classify-path
# ..instrumented #'metabase.models.permissions/classify-data-path
# ..instrumented #'metabase.models.permissions/generate-graph
# ..instrumented #'metabase.models.permissions/->v2-path
# ..instrumented #'metabase.models.permissions/update-db-data-access-permissions!
# ..instrumented #'metabase.models.permissions/update-group-permissions!
# ..instrumented #'metabase.models.permissions/update-data-perms-graph!
# ..instrumented #'metabase.models.parameter-card/upsert-or-delete-from-parameters!
# WARNING: abs already refers to: #'clojure.core/abs in namespace: kixi.stats.math, being replaced by: #'kixi.stats.math/abs
# WARNING: abs already refers to: #'clojure.core/abs in namespace: kixi.stats.test, being replaced by: #'kixi.stats.math/abs
# WARNING: abs already refers to: #'clojure.core/abs in namespace: kixi.stats.distribution, being replaced by: #'kixi.stats.math/abs
# ..instrumented #'metabase.query-processor.middleware.permissions/check-query-permissions*
# ..instrumented #'metabase.driver.sql-jdbc.sync.describe-database/simple-select-probe-query
# 2023-05-13 10:58:56,780 INFO driver.impl :: Registered abstract driver :sql  🚚
# 2023-05-13 10:58:56,784 INFO metabase.util ::  ⮦ Load driver :sql took 71.9 ms
# 2023-05-13 10:58:56,787 INFO driver.impl :: Registered abstract driver :sql-jdbc (parents: [:sql]) 🚚
# 2023-05-13 10:58:56,790 INFO metabase.util :: Load driver :sql-jdbc took 81.5 ms
# 2023-05-13 10:58:56,790 INFO driver.impl :: Registered driver :h2 (parents: [:sql-jdbc]) 🚚
# ..instrumented #'metabase.driver.h2/classify-query
# 2023-05-13 10:58:56,830 INFO driver.impl :: Registered driver :mysql (parents: [:sql-jdbc]) 🚚
# 2023-05-13 10:58:56,854 INFO driver.impl :: Registered driver :postgres (parents: [:sql-jdbc]) 🚚
# ..instrumented #'metabase.models.params.custom-values/values-from-card
# ..instrumented #'metabase.api.card/param-values
# ..instrumented #'metabase.api.dashboard/chain-filter
# 2023-05-13 10:58:58,316 INFO metabase.core ::
# Metabase v0.46.0 (0ca7df3 release-x.46.x)
#
# Copyright © 2023 Metabase, Inc.
#
# Metabase Enterprise Edition extensions are NOT PRESENT.
# 2023-05-13 10:58:58,324 INFO metabase.core :: Starting Metabase in STANDALONE mode
# 2023-05-13 10:58:58,373 INFO metabase.server :: Launching Embedded Jetty Webserver with config:
#  {:port 3000}
#
# 2023-05-13 10:58:58,422 INFO metabase.core :: Starting Metabase version v0.46.0 (0ca7df3 release-x.46.x) ...
# 2023-05-13 10:58:58,448 INFO metabase.core :: System info:
#  {"file.encoding" "UTF-8",
#  "java.runtime.name" "OpenJDK Runtime Environment",
#  "java.runtime.version" "11.0.19+7-LTS",
#  "java.vendor" "Azul Systems, Inc.",
#  "java.vendor.url" "http://www.azul.com/",
#  "java.version" "11.0.19",
#  "java.vm.name" "OpenJDK 64-Bit Server VM",
#  "java.vm.version" "11.0.19+7-LTS",
#  "os.name" "Linux",
#  "os.version" "6.1.27-060127-generic",
#  "user.language" "en",
#  "user.timezone" "GMT"}
#
# 2023-05-13 10:58:58,450 INFO metabase.plugins :: Loading plugins in /workspace/meta/metabase/plugins...
# 2023-05-13 10:58:58,577 INFO util.files :: Extract file /modules/sparksql.metabase-driver.jar -> /workspace/meta/metabase/plugins/sparksql.metabase-driver.jar
# 2023-05-13 10:58:58,630 INFO util.files :: Extract file /modules/athena.metabase-driver.jar -> /workspace/meta/metabase/plugins/athena.metabase-driver.jar
# 2023-05-13 10:58:58,700 INFO util.files :: Extract file /modules/sqlserver.metabase-driver.jar -> /workspace/meta/metabase/plugins/sqlserver.metabase-driver.jar
# 2023-05-13 10:58:58,707 INFO util.files :: Extract file /modules/presto-jdbc.metabase-driver.jar -> /workspace/meta/metabase/plugins/presto-jdbc.metabase-driver.jar
# 2023-05-13 10:58:58,751 INFO util.files :: Extract file /modules/sqlite.metabase-driver.jar -> /workspace/meta/metabase/plugins/sqlite.metabase-driver.jar
# 2023-05-13 10:58:58,769 INFO util.files :: Extract file /modules/vertica.metabase-driver.jar -> /workspace/meta/metabase/plugins/vertica.metabase-driver.jar
# 2023-05-13 10:58:58,770 INFO util.files :: Extract file /modules/redshift.metabase-driver.jar -> /workspace/meta/metabase/plugins/redshift.metabase-driver.jar
# 2023-05-13 10:58:58,775 INFO util.files :: Extract file /modules/druid.metabase-driver.jar -> /workspace/meta/metabase/plugins/druid.metabase-driver.jar
# 2023-05-13 10:58:58,778 INFO util.files :: Extract file /modules/mongo.metabase-driver.jar -> /workspace/meta/metabase/plugins/mongo.metabase-driver.jar
# 2023-05-13 10:58:58,792 INFO util.files :: Extract file /modules/oracle.metabase-driver.jar -> /workspace/meta/metabase/plugins/oracle.metabase-driver.jar
# 2023-05-13 10:58:58,793 INFO util.files :: Extract file /modules/snowflake.metabase-driver.jar -> /workspace/meta/metabase/plugins/snowflake.metabase-driver.jar
# 2023-05-13 10:58:58,945 INFO util.files :: Extract file /modules/googleanalytics.metabase-driver.jar -> /workspace/meta/metabase/plugins/googleanalytics.metabase-driver.jar
# 2023-05-13 10:58:58,954 INFO util.files :: Extract file /modules/bigquery-cloud-sdk.metabase-driver.jar -> /workspace/meta/metabase/plugins/bigquery-cloud-sdk.metabase-driver.jar
# 2023-05-13 10:58:59,112 INFO plugins.dependencies :: Plugin 'Metabase BigQuery Driver' depends on plugin 'Metabase Google Drivers Shared Dependencies'
# 2023-05-13 10:58:59,113 INFO plugins.dependencies :: Metabase BigQuery Driver dependency {:plugin Metabase Google Drivers Shared Dependencies} satisfied? false
# 2023-05-13 10:58:59,114 INFO plugins.dependencies :: Plugins with unsatisfied deps: ["Metabase BigQuery Driver"]
# 2023-05-13 10:58:59,119 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :presto...
# 2023-05-13 10:58:59,119 INFO driver.impl :: Registered driver :presto (parents: [:sql]) 🚚
# 2023-05-13 10:58:59,122 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :google...
# 2023-05-13 10:58:59,122 INFO driver.impl :: Registered abstract driver :google  🚚
# 2023-05-13 10:58:59,123 INFO plugins.dependencies :: Metabase BigQuery Driver dependency {:plugin Metabase Google Drivers Shared Dependencies} satisfied? true
# 2023-05-13 10:58:59,123 DEBUG plugins.initialize :: Dependencies satisfied; these plugins will now be loaded: ["Metabase BigQuery Driver"]
# 2023-05-13 10:58:59,123 WARN plugins.lazy-loaded-driver :: Warning: plugin manifest for :bigquery does not include connection properties
# 2023-05-13 10:58:59,124 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :bigquery...
# 2023-05-13 10:58:59,124 INFO driver.impl :: Registered driver :bigquery (parents: [:sql :google]) 🚚
# 2023-05-13 10:58:59,131 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :hive-like...
# 2023-05-13 10:58:59,132 INFO driver.impl :: Registered abstract driver :hive-like (parents: [:sql-jdbc]) 🚚
# 2023-05-13 10:58:59,132 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :sparksql...
# 2023-05-13 10:58:59,133 INFO driver.impl :: Registered driver :sparksql (parents: [:hive-like]) 🚚
# 2023-05-13 10:58:59,145 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :athena...
# 2023-05-13 10:58:59,146 INFO driver.impl :: Registered driver :athena (parents: [:sql-jdbc]) 🚚
# 2023-05-13 10:58:59,150 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :sqlserver...
# 2023-05-13 10:58:59,150 INFO driver.impl :: Registered driver :sqlserver (parents: [:sql-jdbc]) 🚚
# 2023-05-13 10:58:59,161 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :presto-jdbc...
# 2023-05-13 10:58:59,161 INFO driver.impl :: Registered driver :presto-jdbc (parents: [:sql-jdbc]) 🚚
# 2023-05-13 10:58:59,163 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :sqlite...
# 2023-05-13 10:58:59,164 INFO driver.impl :: Registered driver :sqlite (parents: [:sql-jdbc]) 🚚
# 2023-05-13 10:58:59,166 INFO plugins.dependencies :: Metabase cannot initialize plugin Metabase Vertica Driver due to required dependencies. Metabase requires the Vertica JDBC driver in order to connect to Vertica databases, but we can't ship it as part of Metabase due to licensing restrictions. See https://metabase.com/docs/latest/administration-guide/databases/vertica.html for more details.
#
# 2023-05-13 10:58:59,166 INFO plugins.dependencies :: Metabase Vertica Driver dependency {:class com.vertica.jdbc.Driver} satisfied? false
# 2023-05-13 10:58:59,167 INFO plugins.dependencies :: Plugins with unsatisfied deps: ["Metabase Vertica Driver"]
# 2023-05-13 10:58:59,169 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :redshift...
# 2023-05-13 10:58:59,169 INFO driver.impl :: Registered driver :redshift (parents: [:postgres]) 🚚
# 2023-05-13 10:58:59,171 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :druid...
# 2023-05-13 10:58:59,172 INFO driver.impl :: Registered driver :druid  🚚
# 2023-05-13 10:58:59,176 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :mongo...
# 2023-05-13 10:58:59,176 INFO driver.impl :: Registered driver :mongo  🚚
# 2023-05-13 10:58:59,180 INFO plugins.dependencies :: Metabase cannot initialize plugin Metabase Oracle Driver due to required dependencies. Metabase requires the Oracle JDBC driver in order to connect to Oracle databases, but we can't ship it as part of Metabase due to licensing restrictions. See https://metabase.com/docs/latest/administration-guide/databases/oracle.html for more details.
#
# 2023-05-13 10:58:59,181 INFO plugins.dependencies :: Metabase Oracle Driver dependency {:class oracle.jdbc.OracleDriver} satisfied? false
# 2023-05-13 10:58:59,182 INFO plugins.dependencies :: Plugins with unsatisfied deps: ["Metabase Vertica Driver" "Metabase Oracle Driver"]
# 2023-05-13 10:58:59,203 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :snowflake...
# 2023-05-13 10:58:59,204 INFO driver.impl :: Registered driver :snowflake (parents: [:sql-jdbc]) 🚚
# 2023-05-13 10:58:59,207 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :googleanalytics...
# 2023-05-13 10:58:59,207 INFO driver.impl :: Registered driver :googleanalytics  🚚
# 2023-05-13 10:58:59,212 DEBUG plugins.lazy-loaded-driver :: Registering lazy loading driver :bigquery-cloud-sdk...
# 2023-05-13 10:58:59,213 INFO driver.impl :: Registered driver :bigquery-cloud-sdk (parents: [:sql]) 🚚
# 2023-05-13 10:58:59,213 INFO metabase.core :: Setting up and migrating Metabase DB. Please sit tight, this may take a minute...
# 2023-05-13 10:58:59,216 INFO db.setup :: Verifying h2 Database Connection ...
# 2023-05-13 10:58:59,242 INFO db.update-h2 :: H2 v1 database detected, updating...
# 2023-05-13 10:58:59,243 INFO db.update-h2 :: Downloading https://repo1.maven.org/maven2/com/h2database/h2/1.4.197/h2-1.4.197.jar
# 2023-05-13 10:58:59,914 INFO db.update-h2 :: Creating v1 database backup at /tmp/metabase-migrate-h2-db-v1-v2.sql
# 2023-05-13 10:59:00,493 INFO db.update-h2 :: Moving old app database to /workspace/meta/metabase/metabase.db.v1-backup.mv.db
# 2023-05-13 10:59:00,495 INFO db.update-h2 :: Restoring backup into v2 database
# 2023-05-13 10:59:00,932 INFO db.update-h2 :: Backup restored into H2 v2 database. Update complete!
# 2023-05-13 10:59:00,976 INFO db.setup :: Successfully verified H2 2.1.212 (2022-04-09) application database connection. ✅
# 2023-05-13 10:59:00,978 INFO db.setup :: Running Database Migrations...
# 2023-05-13 10:59:00,980 INFO db.setup :: Setting up Liquibase...
# 2023-05-13 10:59:01,131 INFO db.setup :: Liquibase is ready.
# 2023-05-13 10:59:01,131 INFO db.liquibase :: Checking if Database has unrun migrations...
# 2023-05-13 10:59:02,966 INFO db.liquibase :: Database has unrun migrations. Waiting for migration lock to be cleared...
# 2023-05-13 10:59:03,330 INFO db.liquibase :: Migration lock is cleared. Running migrations...
# 2023-05-13 10:59:05,387 INFO impl.StdSchedulerFactory :: Using default implementation for ThreadExecutor
# 2023-05-13 10:59:05,403 INFO core.SchedulerSignalerImpl :: Initialized Scheduler Signaller of type: class org.quartz.core.SchedulerSignalerImpl
# 2023-05-13 10:59:05,403 INFO core.QuartzScheduler :: Quartz Scheduler v.2.3.2 created.
# 2023-05-13 10:59:05,404 INFO jdbcjobstore.JobStoreTX :: Using db table-based data access locking (synchronization).
# 2023-05-13 10:59:05,406 INFO jdbcjobstore.JobStoreTX :: JobStoreTX initialized.
# 2023-05-13 10:59:05,407 INFO core.QuartzScheduler :: Scheduler meta-data: Quartz Scheduler (v2.3.2) 'MetabaseScheduler' with instanceId 'abdulsaboor938-meta-fqivgh561gb1683975545388'
#   Scheduler class: 'org.quartz.core.QuartzScheduler' - running locally.
#   NOT STARTED.
#   Currently in standby mode.
#   Number of jobs executed: 0
#   Using thread pool 'org.quartz.simpl.SimpleThreadPool' - with 10 threads.
#   Using job-store 'org.quartz.impl.jdbcjobstore.JobStoreTX' - which supports persistence. and is clustered.
#
# 2023-05-13 10:59:05,407 INFO impl.StdSchedulerFactory :: Quartz scheduler 'MetabaseScheduler' initialized from default resource file in Quartz package: 'quartz.properties'
# 2023-05-13 10:59:05,407 INFO impl.StdSchedulerFactory :: Quartz scheduler version: 2.3.2
# 2023-05-13 10:59:05,423 INFO jdbcjobstore.JobStoreTX :: ClusterManager: detected 1 failed or restarted instances.
# 2023-05-13 10:59:05,423 INFO jdbcjobstore.JobStoreTX :: ClusterManager: Scanning for instance "abdulsaboor938-meta-fqivgh561gb1683975330637"'s failed in-progress jobs.
# 2023-05-13 10:59:05,425 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683975545388 started.
# 2023-05-13 10:59:05,434 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683975545388 shutting down.
# 2023-05-13 10:59:05,434 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683975545388 paused.
# 2023-05-13 10:59:05,435 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683975545388 shutdown complete.
# 2023-05-13 10:59:05,444 INFO db.setup :: Database Migrations Current ...  ✅
# 2023-05-13 10:59:05,455 INFO db.data-migrations :: Running all necessary data migrations, this may take a minute.
# 2023-05-13 10:59:05,465 INFO db.data-migrations :: Running data migration 'migrate-remove-admin-from-group-mapping-if-needed'...
# 2023-05-13 10:59:05,520 INFO db.data-migrations :: Finished running data migrations.
# 2023-05-13 10:59:05,521 INFO metabase.util :: Database setup took 6.3 s
# 2023-05-13 10:59:05,563 INFO metabase.events :: Starting events listener: :metabase.events.activity-feed/ActivityFeed 👂
# 2023-05-13 10:59:05,567 INFO metabase.events :: Starting events listener: :metabase.events.last-login/LastLogin 👂
# 2023-05-13 10:59:05,568 INFO metabase.events :: Starting events listener: :metabase.events.persisted-info/PersistedInfo 👂
# 2023-05-13 10:59:05,568 INFO metabase.events :: Starting events listener: :metabase.events.sync-database/Sync 👂
# 2023-05-13 10:59:05,568 INFO metabase.events :: Starting events listener: :metabase.events.driver-notifications/DriverNotifications 👂
# 2023-05-13 10:59:05,568 INFO metabase.events :: Starting events listener: :metabase.events.revision/Revisions 👂
# 2023-05-13 10:59:05,569 INFO metabase.events :: Starting events listener: :metabase.events.view-log/ViewLog 👂
# 2023-05-13 10:59:05,578 INFO metabase.core :: Looks like this is a new installation ... preparing setup wizard
# 2023-05-13 10:59:05,581 INFO metabase.core :: Please use the following URL to setup your Metabase installation:
#
# http://localhost:3000/setup/
#
#
# 2023-05-13 10:59:05,604 INFO impl.StdSchedulerFactory :: Using default implementation for ThreadExecutor
# 2023-05-13 10:59:05,609 INFO core.SchedulerSignalerImpl :: Initialized Scheduler Signaller of type: class org.quartz.core.SchedulerSignalerImpl
# 2023-05-13 10:59:05,609 INFO core.QuartzScheduler :: Quartz Scheduler v.2.3.2 created.
# 2023-05-13 10:59:05,609 INFO jdbcjobstore.JobStoreTX :: Using db table-based data access locking (synchronization).
# 2023-05-13 10:59:05,612 INFO jdbcjobstore.JobStoreTX :: JobStoreTX initialized.
# 2023-05-13 10:59:05,612 INFO core.QuartzScheduler :: Scheduler meta-data: Quartz Scheduler (v2.3.2) 'MetabaseScheduler' with instanceId 'abdulsaboor938-meta-fqivgh561gb1683975545605'
#   Scheduler class: 'org.quartz.core.QuartzScheduler' - running locally.
#   NOT STARTED.
#   Currently in standby mode.
#   Number of jobs executed: 0
#   Using thread pool 'org.quartz.simpl.SimpleThreadPool' - with 10 threads.
#   Using job-store 'org.quartz.impl.jdbcjobstore.JobStoreTX' - which supports persistence. and is clustered.
#
# 2023-05-13 10:59:05,612 INFO impl.StdSchedulerFactory :: Quartz scheduler 'MetabaseScheduler' initialized from default resource file in Quartz package: 'quartz.properties'
# 2023-05-13 10:59:05,613 INFO impl.StdSchedulerFactory :: Quartz scheduler version: 2.3.2
# 2023-05-13 10:59:05,693 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683975545605 paused.
# 2023-05-13 10:59:05,693 INFO metabase.task :: Task scheduler initialized into standby mode.
# 2023-05-13 10:59:05,694 INFO metabase.task :: Initializing task SyncDatabases 📆
# 2023-05-13 10:59:05,742 INFO driver.impl :: Initializing driver :sql...
# 2023-05-13 10:59:05,742 INFO driver.impl :: Initializing driver :sql-jdbc...
# 2023-05-13 10:59:05,743 INFO driver.impl :: Initializing driver :h2...
# 2023-05-13 10:59:05,753 INFO models.database :: :h2 Database 'Sample Database' sync/analyze schedules have changed!
#  Sync metadata was: '0 50 * * * ? *' is now: '0 48 * * * ? *'
#  Cache FieldValues was: '0 50 0 * * ? *', is now: '0 0 1 * * ? *'
# 2023-05-13 10:59:05,784 INFO task.sync-databases :: Scheduling sync/analyze for database 1: trigger: metabase.task.sync-and-analyze.trigger.1
# 2023-05-13 10:59:05,793 INFO task.sync-databases :: Scheduling field-values for database 1: trigger: metabase.task.update-field-values.trigger.1
# 2023-05-13 10:59:05,805 INFO task.sync-databases :: Updated default schedules for 1 databases
# 2023-05-13 10:59:05,806 INFO metabase.task :: Initializing task PersistRefresh 📆
# 2023-05-13 10:59:05,814 INFO metabase.task :: Initializing task CheckForNewVersions 📆
# 2023-05-13 10:59:05,822 INFO metabase.task :: Initializing task PersistPrune 📆
# 2023-05-13 10:59:05,823 INFO metabase.task :: Initializing task SendAnonymousUsageStats 📆
# 2023-05-13 10:59:05,828 INFO metabase.task :: Initializing task RefreshSlackChannelsAndUsers 📆
# 2023-05-13 10:59:05,831 INFO metabase.task :: Initializing task SendPulses 📆
# 2023-05-13 10:59:05,836 INFO metabase.task :: Initializing task SendFollowUpEmails 📆
# 2023-05-13 10:59:05,840 INFO metabase.task :: Initializing task TaskHistoryCleanup 📆
# 2023-05-13 10:59:05,845 INFO metabase.task :: Initializing task TruncateAuditLog 📆
# 2023-05-13 10:59:05,848 INFO core.QuartzScheduler :: Scheduler MetabaseScheduler_$_abdulsaboor938-meta-fqivgh561gb1683975545605 started.
# 2023-05-13 10:59:05,848 INFO metabase.task :: Task scheduler started
# 2023-05-13 10:59:05,849 INFO metabase.core :: Metabase Initialization COMPLETE
# 2023-05-13 10:59:05,861 INFO task.refresh-slack-channel-user-cache :: Slack is not configured, not refreshing slack user/channel cache.
# 2023-05-13 10:59:20,849 INFO jdbcjobstore.JobStoreTX :: ClusterManager: detected 1 failed or restarted instances.
# 2023-05-13 10:59:20,849 INFO jdbcjobstore.JobStoreTX :: ClusterManager: Scanning for instance "abdulsaboor938-meta-fqivgh561gb1683975545388"'s failed in-progress jobs.
# 2023-05-13 10:59:52,878 INFO i18n.impl :: Reading available locales from locales.clj...
# 2023-05-13 10:59:52,980 INFO util.fonts :: Reading available fonts from /frontend_client/app/fonts
# 2023-05-13 10:59:56,855 DEBUG middleware.log :: GET /api/user/current 401 1.5 ms (0 DB calls)
# "Unauthenticated"
#
# 2023-05-13 10:59:56,872 DEBUG middleware.log :: GET /api/session/properties 200 17.2 ms (2 DB calls) App DB connections: 0/4 Jetty threads: 6/50 (4 idle, 0 queued) (51 total active threads) Queries in flight: 0 (0 queued)
# 2023-05-13 11:00:00,012 INFO task.send-pulses :: Sending scheduled pulses...
